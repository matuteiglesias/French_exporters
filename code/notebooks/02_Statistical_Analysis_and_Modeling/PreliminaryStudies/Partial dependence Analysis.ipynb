# %%
import numpy as np

import matplotlib.pyplot as plt
import seaborn
% matplotlib inline

import pandas as pd

# %% [markdown]
# ### Load

# %%
# # ## Load if needed 
# df_xy1 = pd.read_csv('./../../data/processed/20190712_x0_depce_test_full.csv')
# df_xy2 = pd.read_csv('./../../data/processed/20190712_x0_depce_test_full2.csv')
# df_xy3 = pd.read_csv('./../../data/processed/20190712_x0_depce_test_full3.csv')
# df_xy = pd.concat([df_xy1, df_xy2, df_xy3], axis = 0)

# # scale up
# df_xy['var_qi'] = df_xy['var_qi']/(df_xy.s)**2
# df_xy['y'] = df_xy['y']/(df_xy.s)**2
# df_xy['x0'] = df_xy['x0']/(df_xy.s)**2

# %%
# # fits are already saved scaled
# fits1 = pd.read_csv('./../../data/processed/20190712_x0_depce_test_full_fits1.csv')
# fits2 = pd.read_csv('./../../data/processed/20190712_x0_depce_test_full_fits2.csv')

# fits1['pct'] = (fits1['q'] + .5)/fits1['Q']

# %%
# df_xy = pd.read_csv('./../../data/processed/20190715_depce_test_logn90.csv')
# fits1 = pd.read_csv('./../../data/processed/20190715_depce_test_fits1_logn90.csv')
# fits2 = pd.read_csv('./../../data/processed/20190715_depce_test_fits2_logn90.csv')

df_xy = pd.read_csv('./../../data/processed/20190715_depce_test_logn90_diff_mediant0.csv')
fits1 = pd.read_csv('./../../data/processed/20190715_depce_test_fits1_logn90_diff_median.csv')
fits2 = pd.read_csv('./../../data/processed/20190715_depce_test_fits2_logn90_diff_median.csv')
fits1['pct'] = (fits1['q'] + .5)/fits1['Q']

df_xy['pct'] = (df_xy['q'] + .5)/df_xy['Q']
# df_xy['y/s2'] = df_xy['y']/df_xy['s']**2
# df_xy['ydiff/s2'] = df_xy['ydiff']/df_xy['s']**2

t0var = 'tdiff0'

# %% [markdown]
# ## Analysis

# %%
# # Dependence with Q and s

df_ = fits1#.loc[fits1.dist == 'lapl']
# df_ = df_.loc[abs(df_.pct - .5) <= .25] # the middle qs are more robust in the x0 value

Q_list = [10, 20]
fig, axs = plt.subplots(1, 2, figsize = (7 * len(Q_list), 5))
for i, Q_ in enumerate(Q_list):
    df_Q = df_.loc[df_.Q == Q_]#
#     df_Q['s0'] = (df_Q['s0'].values)/(df_Q['s'].values**2) # This is an option to scale the s0. It is already assumed when the y is scaled... It's incorporated in fits1
    ax = axs[i]    
    ax.set_title(str(Q_))#+', '+str(s_))
    for s_ in df_.s.unique():
        df_Qs = df_Q.loc[df_Q.s == s_]#
        
        df_Qs.plot(t0var, 's0', marker = '.', lw = 0, ax = ax, label = str(s_))
        ym = 1.75
        ax.plot( [0,ym],[0,ym] , color = '.5', linestyle = '--')
        ax.set_xlabel(r'$\sigma^2_{q0}/s^2$')
        ax.set_ylabel('background y0')
        ax.legend()
#         ax.set_xlim(0, 0.025)
        ax.set_ylim(0, ym)

plt.show()
    
# Total var ( the 'y') should not change with Q.
# In the simple gaussian case, and with small volatility of q's we see a linear dependence that points to zero.

# %%
df_xy.head()
# Out:
#    Unnamed: 0  i    var_qi  var_diff_qi      t_qi  tdiff_qi         y  \
# 0           0  1  0.000220     0.000042  0.022030  0.004198  0.000237
# 1           1  2  0.000205     0.000036  0.020513  0.003560  0.000232
# 2           2  3  0.000275     0.000050  0.027530  0.004970  0.000240
# 3           3  5  0.000382     0.000061  0.038180  0.006121  0.000246
# 4           4  6  0.000177     0.000038  0.017668  0.003793  0.000233
#
#       ydiff  q   Q  ...  dist  tdiff0   tdiff0q    var_t0  var_diff_t0  \
# 0  0.000140  0  10  ...  norm  median  0.004534  0.000249     0.000153
# 1  0.000138  0  10  ...  norm  median  0.004534  0.000249     0.000153
# 2  0.000139  0  10  ...  norm  median  0.004534  0.000249     0.000153
# 3  0.000141  0  10  ...  norm  median  0.004534  0.000249     0.000153
# 4  0.000139  0  10  ...  norm  median  0.004534  0.000249     0.000153
#
#        y/s2  ydiff/s2  var_t0/s2  var_diff_t0/s2   pct
# 0  0.023688  0.014007   0.024861        0.015321  0.05
# 1  0.023235  0.013761   0.024861        0.015321  0.05
# 2  0.024027  0.013929   0.024861        0.015321  0.05
# 3  0.024551  0.014129   0.024861        0.015321  0.05
# 4  0.023324  0.013931   0.024861        0.015321  0.05
#
# [5 rows x 21 columns]

# %%
df_xy.head()
# Out:
#    Unnamed: 0  i    var_qi  var_diff_qi      t_qi  tdiff_qi         y  \
# 0           0  1  0.000319     0.000062  0.031939  0.006185  0.000317
# 1           1  2  0.000264     0.000059  0.026433  0.005880  0.000311
# 2           2  3  0.000189     0.000039  0.018921  0.003912  0.000302
# 3           3  4  0.000348     0.000057  0.034833  0.005653  0.000319
# 4           4  6  0.000189     0.000034  0.018871  0.003440  0.000302
#
#       ydiff  q   Q    s  dist  tdiff0   tdiff0q    var_t0  var_diff_t0  \
# 0  0.000077  0  10  0.1  norm  0.0265  0.006247  0.000354      0.00015
# 1  0.000077  0  10  0.1  norm  0.0265  0.006247  0.000354      0.00015
# 2  0.000074  0  10  0.1  norm  0.0265  0.006247  0.000354      0.00015
# 3  0.000076  0  10  0.1  norm  0.0265  0.006247  0.000354      0.00015
# 4  0.000074  0  10  0.1  norm  0.0265  0.006247  0.000354      0.00015
#
#        y/s2  ydiff/s2  var_t0/s2  var_diff_t0/s2   pct
# 0  0.031670  0.007660   0.035429        0.014993  0.05
# 1  0.031146  0.007656   0.035429        0.014993  0.05
# 2  0.030164  0.007445   0.035429        0.014993  0.05
# 3  0.031897  0.007562   0.035429        0.014993  0.05
# 4  0.030247  0.007371   0.035429        0.014993  0.05

# %%
# df_xy.groupby(['s','dist','Q', 't0', 'pct'])
fig, ax = plt.subplots(1, figsize = (15, 10))
sorted_ = df_xy.loc[(df_xy[t0var] == df_xy[t0var].unique()[0]) & ((df_xy.Q == 10))].sort_values(by = ['s', 'Q', 'q', 'tdiff_qi'])
[ax.axvline(l, linestyle = '--') for l in sorted_.groupby(['s','Q', 'q']).count().iloc[:, 0].cumsum().values]
[ax.axvline(l, lw = 2, color = 'k') for l in sorted_.groupby(['s','Q']).count().iloc[:, 0].cumsum().values]
sorted_.reset_index()[['tdiff_qi', 'ydiff/s2']].plot(ax = ax, marker = '.', lw = 0)
ax.set_yscale('log')

# %%
# Attention. We want x0 values to be comfortably reachable. Otherwise I will just be having them clipped for some of the Q, s, q combinations.

values_check = df_xy.reset_index(drop = True).drop(['y', t0var], axis = 1).drop_duplicates().sort_values(by = ['q', 'tdiff_qi'])
# grouped = values_check.loc[(values_check.dist == 'norm')].groupby(['Q', 's', 'q'])
grouped = values_check.groupby(['dist','s', 'q'])

fig, ax = plt.subplots(1, figsize = (17, 5))
grouped.agg(['min', 'max'])['tdiff_qi'].plot(ax = ax)
# ax.axhline(0.01)
# ax.axhline(0.02)
# ax.set_ylim(0, 0.03)
ax.set_yscale('log')

s_dist_grouped = grouped.agg(['min', 'max'])['t_qi'].groupby(level = [0, 1])
x0_s_dist = pd.concat([s_dist_grouped['min'].quantile(.7) + \
           l*(s_dist_grouped['max'].quantile(.3) - s_dist_grouped['min'].quantile(.7)) for l in np.arange(0, 1, .1)], axis = 1).round(4)

df_ = grouped.agg(['min', 'max'])['tdiff_qi'].reset_index().merge(x0_s_dist.reset_index()).set_index(['dist', 's', 'q'])

df_[range(10)].plot(color = '.4', linestyle = '--', ax = ax, legend=False)

plt.show()

# %%
df_ = fits1.loc[fits1.dist == 'norm']
# df_ = df_.loc[abs(df_.pct - .5) <= .25] # the middle qs are more robust in the x0 value

## Dependence with Q

fig, ax = plt.subplots(1, figsize = (7, 5))
aQ = []
for Q_ in df_.Q.unique():
    s_ = .2
    ax.set_title(str(s_))
    data = df_.loc[(df_.Q == Q_) & (df_.s == s_)]
    data.plot(t0var, 's0', marker = '.', lw = 0, ax = ax, label = str(Q_))
    
    line = np.polyfit(data[t0var], data.s0, 1)
    ax.plot(np.arange(0, 2, 0.1), np.arange(0, 2, 0.1)*line[0] + line[1])
    
    ym = 1.75
    ax.plot( [0,ym],[0,ym] , color = '.6', linestyle = '--')
        
        
    print(line.round(3))
    # This is useful for a(Q). For now not a clearly explainable dependence
    aQ += [line[0]]
aQ = np.array(aQ)
# ax.set_xlim(0, 0.025)
# ax.set_ylim(0, 0.04)
ax.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-43bfebf7abd5> in <module>()
#      12     data.plot(t0var, 's0', marker = '.', lw = 0, ax = ax, label = str(Q_))
#      13
# ---> 14     line = np.polyfit(data[t0var], data.s0, 1)
#      15     ax.plot(np.arange(0, 2, 0.1), np.arange(0, 2, 0.1)*line[0] + line[1])
#      16
#
# ~/anaconda2/envs/my_pymc_env/lib/python3.6/site-packages/numpy/lib/polynomial.py in polyfit(x, y, deg, rcond, full, w, cov)
#     539     """
#     540     order = int(deg) + 1
# --> 541     x = NX.asarray(x) + 0.0
#     542     y = NX.asarray(y) + 0.0
#     543
#
# TypeError: must be str, not float

# %% [markdown]
# ### The s0 terms

# %%
s0_describe = fits1.groupby(['dist', 's', t0var])['s0'].describe() # does not depend on Q

s0_describe = s0_describe[['75%', 'mean', '25%']]

fig, ax = plt.subplots(1, figsize = (7,6))
for s_ in s0_describe.loc['norm'].index.get_level_values('s').unique():
    data = s0_describe.loc['norm'].loc[s_].reset_index()
    ax.fill_between(data[t0var], data['25%'], data['75%'], alpha = .2, label = str(s_))
    ax.plot(data[t0var], data['mean'], color = '.7', label = '_')
    ym = 1.75
    ax.plot( [0,ym],[0,ym] , color = '.5', linestyle = '--')
    
# ax.set_xlim(0, 0.25) # Focus on the origin
# ax.set_ylim(0, 0.25)
ax.set_xlabel(r'$\sigma^2_{q0}/s^2$')
ax.set_ylabel('Expected y0')
ax.legend()
plt.show()

# %% [markdown]
# #### Partial derivatives at x0

# %%
# fits2['part_dev_x0'] = 2 * fits2.a * fits2[t0var] + fits2.b
fits1['part_dev_x0'] = fits1.a

df_ = fits1.set_index(['dist']).loc['norm']

part_devs_q = df_.loc[df_.s == .2].groupby(['Q', 'q'])['part_dev_x0'].describe()[['mean', '25%','50%','75%']]
part_devs_q = part_devs_q.reset_index()
part_devs_q['pct'] = (part_devs_q['q'] + .5)/part_devs_q['Q']

fig, ax = plt.subplots(1, figsize = (7, 5))
for Q_ in part_devs_q.Q.unique():
    data = part_devs_q.loc[part_devs_q.Q == Q_]
    ax.fill_between(data.pct, Q_*data['25%'], Q_*data['75%'], alpha = 1)
    ax.plot(data.pct, Q_*data['mean'], alpha = 1)
plt.show()
# High q are the little populated, volatile ones.

# %% [markdown]
# ### The $(\sigma^2_q - \sigma^2_0)$ term
# Computed as difference between median and x0. It is just to have a qualitative idea, cause actually $\sigma^2_q$ will be given in each custom case

# %%
# describe var_qi by dist, Q, q, s (s = .3 for now)
describe = df_xy.loc[df_xy.s == .2].drop(['y',t0var], axis = 1).drop_duplicates().groupby(['dist','Q','q','s'])['var_diff_qi'].describe()
describe = describe.loc['norm']

describe = describe.reset_index()
describe['pct'] = (describe['q'] + .5)/describe['Q']

fig, ax = plt.subplots(1, figsize = (7, 5))
for Q_ in describe.Q.unique():
    data = describe.loc[describe.Q == Q_]
    ax.fill_between(data.pct, data['25%'], Q_*data['75%'], alpha = .1)
    ax.plot(data.pct, data['50%'], color = '.5')
plt.yscale('log')
# plt.ylim(0, 0.2)
plt.show()

# %% [markdown]
# ## A term: $\frac{\partial \sigma^2}{\partial \sigma^2_q} (\sigma^2_q - \sigma^2_0) $
#
# We use as x_0 = 0.02 as it is a quite good approx for all the pcts in the lower part of value.

# %%
# describe var_qi by dist, Q, q, s (s = .3 for now)

s_ = .4
df_ = df_xy.loc[(df_xy.s == s_) & (df_xy.dist == 'norm')]
x0_ = df_.x0.unique()[5]
df_ = df_.loc[df_.x0 == x0_]

# df_ = df_xy.loc[df_xy.s == .4].drop(['x0'], axis = 1).drop_duplicates()
describe_var_q = df_.groupby(['dist','Q','q','s'])[['var_qi', 'y']].describe()

df_ = fits2.loc[(fits2.s == s_) & (fits2.dist == 'norm')]
describe_part_dev_x0 = df_.groupby(['dist','Q', 'q', 's'])[['part_dev_x0']].describe()

describe = pd.concat([describe_var_q, describe_part_dev_x0], axis = 1)
describe = describe.iloc[:, describe.columns.get_level_values(1).isin(['25%','50%','75%'])]

describe = describe.reset_index()
describe['pct'] = (describe['q'] + .5)/describe['Q']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-121-791e2ad4e5bc> in <module>()
#       3 s_ = .4
#       4 df_ = df_xy.loc[(df_xy.s == s_) & (df_xy.dist == 'norm')]
# ----> 5 x0_ = df_.x0.unique()[5]
#       6 df_ = df_.loc[df_.x0 == x0_]
#       7
#
# ~/anaconda2/envs/my_pymc_env/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'x0'

# %%
# I'm trying to reconstruct the y from a sum for all q of  ds/dsq .(sq - s0)

fig, ax = plt.subplots(1, figsize = (7, 5))
for i, Q_ in enumerate([10, 15, 25]):
    y0 = aQ[i] * x0_
    df_ = describe.loc[(describe.dist == 'norm') & (describe.Q == Q_)]
    # Evaluated at the medians:
    yq = Q_ * df_['part_dev_x0']['50%'] * (df_['var_qi']['50%'] - x0_)
    yq = df_['part_dev_x0']['50%'] * (df_['var_qi']['50%'] - x0_)
    ax.plot(df_.pct, yq, marker = '.')
    ax.axhline(y0 , color = '.4')

describe.groupby(['dist', 'Q']).mean()['y'].plot(ax = ax) # Should be always the same value...
plt.ylim(0, 0.7)

plt.show()
# It doesn quite work at the median... may be because, eg. in the median case all (x-x0) are positive, while 
# in particular cases they will be on both sides, therefor counteracting.
# Out:
# /home/miglesia/anaconda2/envs/my_pymc_env/lib/python3.6/site-packages/pandas/core/generic.py:3812: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   new_axis = axis.drop(labels, errors=errors)

# %% [markdown]
# ### xq are medians

# %%
# I'm trying to reconstruct the y from a sum for all q of  ds/dsq .(sq - s0)

fig, ax = plt.subplots(1, figsize = (7, 5))
for i, Q_ in enumerate([10, 15, 25]):
    y0 = aQ[i] * x0_
    df_ = describe.loc[(describe.dist == 'norm') & (describe.Q == Q_)]
    # Evaluated at the medians:
    yq = Q_ * df_['part_dev_x0']['50%'] * (df_['var_qi']['50%'] - 0.019)
    yq = df_['part_dev_x0']['50%'] * (df_['var_qi']['50%'] - x0_)
    ax.plot(df_.pct, yq, marker = '.')
    ax.axhline(y0 , color = '.4')

describe.groupby(['dist', 'Q']).mean()['y'].plot(ax = ax) # Should be always the same value...
# plt.ylim(0, 0.02)

plt.show()
# It doesn quite work at the median... may be because, eg. in the median case all (x-x0) are positive, while 
# in particular cases they will be on both sides, therefor counteracting.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-787-f00916a293d3> in <module>()
#       4 for i, Q_ in enumerate([10, 15, 25]):
#       5     y0 = aQ[i] * x0_
# ----> 6     df_ = describe.loc[(describe.dist == 'norm') & (describe.Q == Q_)]
#       7     # Evaluated at the medians:
#       8     yq = Q_ * df_['part_dev_x0']['50%'] * (df_['var_qi']['50%'] - 0.019)
#
# ~/anaconda2/envs/my_pymc_env/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'dist'

# %% [markdown]
# ### xq are the xqi

# %%
def parabola(x, a, b, c):
    return a*x**2 + b*x + c

# %%
# # debug random parabola fits

# for i, row in df_xy[['dist', 's', 'x0', 'Q', 'q']].drop_duplicates().sample(5).iterrows():
#     print(row)
#     dist, s, x0, Q, q = tuple(row)
#     fit_pars = fits2.loc[(fits2.dist == dist) & (fits2.s == s) & (fits2.x0 == x0) & (fits2.Q == Q) & (fits2.q == q)]
#     points = df_xy.loc[(df_xy.dist == dist) & (df_xy.s == s) & (df_xy.x0 == x0) & (df_xy.Q == Q) & (df_xy.q == q)]

#     x = np.arange(0, 1, .1)
#     y = parabola(x, *tuple(fit_pars[['a', 'b', 'c']].values[0]))


#     plt.scatter(points.var_qi, points.y, marker = '.', alpha = .3)
#     plt.plot(x, y, color = 'r')
#     plt.xlim(0, 1)
#     plt.ylim(0, 1)
#     plt.show()

# %%
# plt.scatter(x = fits2['s0'].values, y = fits1['s0'].values, marker = '.')
# plt.show()
# fits2['s0'].values
# Its quite the same except when the parabolas go crazy.

# %%
fits1['part_dev_x0'] = fits1.a

# fits2['part_dev_x0'] = 2 * fits2.a * fits2.x0 + fits2.b
# fits2['s0'] = fits1.s0 # a * fits2.x0**2 + fits2.b * fits2.x0 + fits2.c
# fits2.loc[(fits2.dist == 'norm') & (fits2.s == .4)].sort_values(by = ['q','Q', 's','dist','x0'])
# fits2

# For t - t0 I need the df_xy here
# Hope this works, but it's not guaranteed
# df_xy['i'] = np.array((10 + 15 + 20 + 25)*2*10*5*list(range(500)))

merged = df_xy.merge(fits1, on = ['dist', 's', t0var, 'Q', 'q', t0var+'q'])

merged['tqi - t0q'] = merged['var_diff_qi'] - merged[t0var+'q']
# merged['tqi - t0'] = merged['var_diff_qi'] - merged[t0var]
#

# Now make the columns that have the Q, q series terms...
merged['series_term_Qqi'] = merged['tqi - t0q']*merged['part_dev_x0']

# %%
# fig, ax = plt.subplots(1, figsize = (16, 8))
# merged[['s0', 'var_diff_t0/s2']].drop_duplicates().plot(ax = ax)

# %%
pd.options.display.max_columns = 40
merged
# Out:
#        Unnamed: 0    i    var_qi  var_diff_qi      t_qi  tdiff_qi         y  \
# 0               0    1  0.000319     0.000062  0.031939  0.006185  0.000317
# 1               1    2  0.000264     0.000059  0.026433  0.005880  0.000311
# 2               2    3  0.000189     0.000039  0.018921  0.003912  0.000302
# 3               3    4  0.000348     0.000057  0.034833  0.005653  0.000319
# 4               4    6  0.000189     0.000034  0.018871  0.003440  0.000302
# 5               5    7  0.000213     0.000046  0.021297  0.004603  0.000307
# 6               6    8  0.000286     0.000055  0.028578  0.005487  0.000313
# 7               7    9  0.000325     0.000052  0.032543  0.005248  0.000314
# 8               8   14  0.000220     0.000044  0.022008  0.004381  0.000308
# 9               9   17  0.000218     0.000048  0.021805  0.004771  0.000306
# 10             10   21  0.000244     0.000045  0.024378  0.004540  0.000307
# 11             11   22  0.000196     0.000042  0.019612  0.004220  0.000304
# 12             12   23  0.000272     0.000052  0.027183  0.005233  0.000313
# 13             13   29  0.000296     0.000051  0.029565  0.005120  0.000315
# 14             14   31  0.000265     0.000047  0.026468  0.004663  0.000309
# 15             15   34  0.000193     0.000037  0.019262  0.003676  0.000305
# 16             16   35  0.000274     0.000050  0.027423  0.005022  0.000312
# 17             17   38  0.000279     0.000055  0.027915  0.005451  0.000312
# 18             18   42  0.000206     0.000039  0.020633  0.003853  0.000306
# 19             19   43  0.000324     0.000061  0.032442  0.006126  0.000313
# 20             20   44  0.000202     0.000038  0.020207  0.003815  0.000305
# 21             21   45  0.000236     0.000049  0.023581  0.004913  0.000309
# 22             22   47  0.000326     0.000061  0.032638  0.006072  0.000318
# 23             23   49  0.000251     0.000050  0.025066  0.004990  0.000310
# 24             24   50  0.000217     0.000052  0.021716  0.005217  0.000307
# 25             25   53  0.000238     0.000046  0.023787  0.004582  0.000309
# 26             26   54  0.000249     0.000048  0.024894  0.004813  0.000310
# 27             27   58  0.000236     0.000049  0.023562  0.004912  0.000309
# 28             28   62  0.000302     0.000062  0.030218  0.006219  0.000315
# 29             29   63  0.000172     0.000044  0.017161  0.004383  0.000301
# ...           ...  ...       ...          ...       ...       ...       ...
# 50370        5970  549  0.037521     0.031780  0.938013  0.794492  0.010834
# 50371        5971  550  0.030495     0.027935  0.762376  0.698374  0.011106
# 50372        5972  551  0.058854     0.055122  1.471344  1.378039  0.012590
# 50373        5973  552  0.022744     0.036202  0.568589  0.905043  0.011470
# 50374        5974  553  0.042729     0.036070  1.068234  0.901746  0.013342
# 50375        5975  555  0.022934     0.043978  0.573359  1.099443  0.011721
# 50376        5976  556  0.056684     0.045980  1.417097  1.149502  0.011258
# 50377        5977  557  0.073055     0.056222  1.826363  1.405540  0.010756
# 50378        5978  561  0.082770     0.038965  2.069254  0.974115  0.011121
# 50379        5979  563  0.085110     0.058759  2.127759  1.468963  0.015355
# 50380        5980  569  0.035307     0.036728  0.882666  0.918209  0.010783
# 50381        5981  570  0.120244     0.055621  3.006094  1.390533  0.009261
# 50382        5982  571  0.024517     0.010380  0.612914  0.259494  0.011806
# 50383        5983  572  0.016218     0.018308  0.405442  0.457708  0.010943
# 50384        5984  573  0.036190     0.032437  0.904762  0.810917  0.011394
# 50385        5985  576  0.044951     0.038186  1.123787  0.954650  0.011296
# 50386        5986  578  0.044770     0.017159  1.119262  0.428974  0.009824
# 50387        5987  579  0.020720     0.024442  0.518003  0.611056  0.010733
# 50388        5988  580  0.051410     0.045500  1.285253  1.137488  0.010631
# 50389        5989  585  0.059725     0.051840  1.493113  1.296007  0.010995
# 50390        5990  586  0.055039     0.060700  1.375977  1.517494  0.011378
# 50391        5991  587  0.064027     0.052940  1.600686  1.323502  0.011176
# 50392        5992  589  0.045301     0.040861  1.132537  1.021532  0.010961
# 50393        5993  591  0.016944     0.023047  0.423612  0.576164  0.011280
# 50394        5994  592  0.074306     0.028812  1.857646  0.720303  0.012025
# 50395        5995  593  0.045260     0.062975  1.131492  1.574364  0.011323
# 50396        5996  596  0.021710     0.038188  0.542747  0.954707  0.011183
# 50397        5997  597  0.042747     0.020249  1.068663  0.506216  0.010401
# 50398        5998  598  0.030297     0.055992  0.757433  1.399808  0.011619
# 50399        5999  599  0.026892     0.065389  0.672312  1.634732  0.011385
#
#           ydiff   q   Q    s  dist  tdiff0   tdiff0q    var_t0  var_diff_t0  \
# 0      0.000077   0  10  0.1  norm  0.0265  0.006247  0.000354      0.00015
# 1      0.000077   0  10  0.1  norm  0.0265  0.006247  0.000354      0.00015
# 2      0.000074   0  10  0.1  norm  0.0265  0.006247  0.000354      0.00015
# 3      0.000076   0  10  0.1  norm  0.0265  0.006247  0.000354      0.00015
# 4      0.000074   0  10  0.1  norm  0.0265  0.006247  0.000354      0.00015
# 5      0.000075   0  10  0.1  norm  0.0265  0.006247  0.000354      0.00015
# 6      0.000076   0  10  0.1  norm  0.0265  0.006247  0.000354      0.00015
# 7      0.000075   0  10  0.1  norm  0.0265  0.006247  0.000354      0.00015
# 8      0.000076   0  10  0.1  norm  0.0265  0.006247  0.000354      0.00015
# 9      0.000075   0  10  0.1  norm  0.0265  0.006247  0.000354      0.00015
# 10     0.000075   0  10  0.1  norm  0.0265  0.006247  0.000354      0.00015
# 11     0.000074   0  10  0.1  norm  0.0265  0.006247  0.000354      0.00015
# 12     0.000076   0  10  0.1  norm  0.0265  0.006247  0.000354      0.00015
# 13     0.000076   0  10  0.1  norm  0.0265  0.006247  0.000354      0.00015
# 14     0.000074   0  10  0.1  norm  0.0265  0.006247  0.000354      0.00015
# 15     0.000075   0  10  0.1  norm  0.0265  0.006247  0.000354      0.00015
# 16     0.000075   0  10  0.1  norm  0.0265  0.006247  0.000354      0.00015
# 17     0.000076   0  10  0.1  norm  0.0265  0.006247  0.000354      0.00015
# 18     0.000074   0  10  0.1  norm  0.0265  0.006247  0.000354      0.00015
# 19     0.000075   0  10  0.1  norm  0.0265  0.006247  0.000354      0.00015
# 20     0.000074   0  10  0.1  norm  0.0265  0.006247  0.000354      0.00015
# 21     0.000075   0  10  0.1  norm  0.0265  0.006247  0.000354      0.00015
# 22     0.000076   0  10  0.1  norm  0.0265  0.006247  0.000354      0.00015
# 23     0.000075   0  10  0.1  norm  0.0265  0.006247  0.000354      0.00015
# 24     0.000076   0  10  0.1  norm  0.0265  0.006247  0.000354      0.00015
# 25     0.000075   0  10  0.1  norm  0.0265  0.006247  0.000354      0.00015
# 26     0.000076   0  10  0.1  norm  0.0265  0.006247  0.000354      0.00015
# 27     0.000075   0  10  0.1  norm  0.0265  0.006247  0.000354      0.00015
# 28     0.000076   0  10  0.1  norm  0.0265  0.006247  0.000354      0.00015
# 29     0.000075   0  10  0.1  norm  0.0265  0.006247  0.000354      0.00015
# ...         ...  ..  ..  ...   ...     ...       ...       ...          ...
# 50370  0.002513  19  20  0.2  norm  0.5672  0.568493  0.011385      0.00270
# 50371  0.002311  19  20  0.2  norm  0.5672  0.568493  0.011385      0.00270
# 50372  0.002921  19  20  0.2  norm  0.5672  0.568493  0.011385      0.00270
# 50373  0.002534  19  20  0.2  norm  0.5672  0.568493  0.011385      0.00270
# 50374  0.002947  19  20  0.2  norm  0.5672  0.568493  0.011385      0.00270
# 50375  0.002539  19  20  0.2  norm  0.5672  0.568493  0.011385      0.00270
# 50376  0.002517  19  20  0.2  norm  0.5672  0.568493  0.011385      0.00270
# 50377  0.002232  19  20  0.2  norm  0.5672  0.568493  0.011385      0.00270
# 50378  0.002505  19  20  0.2  norm  0.5672  0.568493  0.011385      0.00270
# 50379  0.003436  19  20  0.2  norm  0.5672  0.568493  0.011385      0.00270
# 50380  0.002589  19  20  0.2  norm  0.5672  0.568493  0.011385      0.00270
# 50381  0.002458  19  20  0.2  norm  0.5672  0.568493  0.011385      0.00270
# 50382  0.002561  19  20  0.2  norm  0.5672  0.568493  0.011385      0.00270
# 50383  0.002446  19  20  0.2  norm  0.5672  0.568493  0.011385      0.00270
# 50384  0.002319  19  20  0.2  norm  0.5672  0.568493  0.011385      0.00270
# 50385  0.002281  19  20  0.2  norm  0.5672  0.568493  0.011385      0.00270
# 50386  0.002214  19  20  0.2  norm  0.5672  0.568493  0.011385      0.00270
# 50387  0.002186  19  20  0.2  norm  0.5672  0.568493  0.011385      0.00270
# 50388  0.002397  19  20  0.2  norm  0.5672  0.568493  0.011385      0.00270
# 50389  0.002324  19  20  0.2  norm  0.5672  0.568493  0.011385      0.00270
# 50390  0.002643  19  20  0.2  norm  0.5672  0.568493  0.011385      0.00270
# 50391  0.002363  19  20  0.2  norm  0.5672  0.568493  0.011385      0.00270
# 50392  0.002309  19  20  0.2  norm  0.5672  0.568493  0.011385      0.00270
# 50393  0.002493  19  20  0.2  norm  0.5672  0.568493  0.011385      0.00270
# 50394  0.002478  19  20  0.2  norm  0.5672  0.568493  0.011385      0.00270
# 50395  0.002369  19  20  0.2  norm  0.5672  0.568493  0.011385      0.00270
# 50396  0.002316  19  20  0.2  norm  0.5672  0.568493  0.011385      0.00270
# 50397  0.002089  19  20  0.2  norm  0.5672  0.568493  0.011385      0.00270
# 50398  0.002568  19  20  0.2  norm  0.5672  0.568493  0.011385      0.00270
# 50399  0.002700  19  20  0.2  norm  0.5672  0.568493  0.011385      0.00270
#
#            y/s2  ydiff/s2  var_t0/s2  var_diff_t0/s2  pct_x         a  \
# 0      0.031670  0.007660   0.035429        0.014993  0.050  0.107008
# 1      0.031146  0.007656   0.035429        0.014993  0.050  0.107008
# 2      0.030164  0.007445   0.035429        0.014993  0.050  0.107008
# 3      0.031897  0.007562   0.035429        0.014993  0.050  0.107008
# 4      0.030247  0.007371   0.035429        0.014993  0.050  0.107008
# 5      0.030673  0.007540   0.035429        0.014993  0.050  0.107008
# 6      0.031347  0.007604   0.035429        0.014993  0.050  0.107008
# 7      0.031404  0.007505   0.035429        0.014993  0.050  0.107008
# 8      0.030830  0.007554   0.035429        0.014993  0.050  0.107008
# 9      0.030588  0.007525   0.035429        0.014993  0.050  0.107008
# 10     0.030736  0.007456   0.035429        0.014993  0.050  0.107008
# 11     0.030371  0.007390   0.035429        0.014993  0.050  0.107008
# 12     0.031281  0.007630   0.035429        0.014993  0.050  0.107008
# 13     0.031459  0.007599   0.035429        0.014993  0.050  0.107008
# 14     0.030924  0.007448   0.035429        0.014993  0.050  0.107008
# 15     0.030460  0.007461   0.035429        0.014993  0.050  0.107008
# 16     0.031207  0.007499   0.035429        0.014993  0.050  0.107008
# 17     0.031245  0.007640   0.035429        0.014993  0.050  0.107008
# 18     0.030591  0.007392   0.035429        0.014993  0.050  0.107008
# 19     0.031268  0.007539   0.035429        0.014993  0.050  0.107008
# 20     0.030527  0.007409   0.035429        0.014993  0.050  0.107008
# 21     0.030899  0.007550   0.035429        0.014993  0.050  0.107008
# 22     0.031806  0.007637   0.035429        0.014993  0.050  0.107008
# 23     0.031038  0.007518   0.035429        0.014993  0.050  0.107008
# 24     0.030741  0.007649   0.035429        0.014993  0.050  0.107008
# 25     0.030881  0.007492   0.035429        0.014993  0.050  0.107008
# 26     0.031022  0.007598   0.035429        0.014993  0.050  0.107008
# 27     0.030862  0.007481   0.035429        0.014993  0.050  0.107008
# 28     0.031456  0.007597   0.035429        0.014993  0.050  0.107008
# 29     0.030124  0.007488   0.035429        0.014993  0.050  0.107008
# ...         ...       ...        ...             ...    ...       ...
# 50370  0.270840  0.062814   0.284628        0.067504  0.975  0.003045
# 50371  0.277658  0.057763   0.284628        0.067504  0.975  0.003045
# 50372  0.314759  0.073021   0.284628        0.067504  0.975  0.003045
# 50373  0.286759  0.063347   0.284628        0.067504  0.975  0.003045
# 50374  0.333543  0.073682   0.284628        0.067504  0.975  0.003045
# 50375  0.293023  0.063476   0.284628        0.067504  0.975  0.003045
# 50376  0.281449  0.062917   0.284628        0.067504  0.975  0.003045
# 50377  0.268906  0.055795   0.284628        0.067504  0.975  0.003045
# 50378  0.278021  0.062613   0.284628        0.067504  0.975  0.003045
# 50379  0.383886  0.085893   0.284628        0.067504  0.975  0.003045
# 50380  0.269587  0.064727   0.284628        0.067504  0.975  0.003045
# 50381  0.231514  0.061443   0.284628        0.067504  0.975  0.003045
# 50382  0.295139  0.064033   0.284628        0.067504  0.975  0.003045
# 50383  0.273577  0.061150   0.284628        0.067504  0.975  0.003045
# 50384  0.284840  0.057983   0.284628        0.067504  0.975  0.003045
# 50385  0.282389  0.057025   0.284628        0.067504  0.975  0.003045
# 50386  0.245603  0.055352   0.284628        0.067504  0.975  0.003045
# 50387  0.268314  0.054653   0.284628        0.067504  0.975  0.003045
# 50388  0.265775  0.059919   0.284628        0.067504  0.975  0.003045
# 50389  0.274880  0.058095   0.284628        0.067504  0.975  0.003045
# 50390  0.284451  0.066070   0.284628        0.067504  0.975  0.003045
# 50391  0.279390  0.059069   0.284628        0.067504  0.975  0.003045
# 50392  0.274032  0.057727   0.284628        0.067504  0.975  0.003045
# 50393  0.282012  0.062331   0.284628        0.067504  0.975  0.003045
# 50394  0.300624  0.061959   0.284628        0.067504  0.975  0.003045
# 50395  0.283085  0.059217   0.284628        0.067504  0.975  0.003045
# 50396  0.279578  0.057903   0.284628        0.067504  0.975  0.003045
# 50397  0.260026  0.052214   0.284628        0.067504  0.975  0.003045
# 50398  0.290474  0.064189   0.284628        0.067504  0.975  0.003045
# 50399  0.284628  0.067504   0.284628        0.067504  0.975  0.003045
#
#               b        s0  pct_y  part_dev_x0  tqi - t0q  tqi - t0  \
# 0      0.007016  0.009852  0.050     0.107008  -0.006185 -0.026438
# 1      0.007016  0.009852  0.050     0.107008  -0.006188 -0.026441
# 2      0.007016  0.009852  0.050     0.107008  -0.006208 -0.026461
# 3      0.007016  0.009852  0.050     0.107008  -0.006190 -0.026443
# 4      0.007016  0.009852  0.050     0.107008  -0.006212 -0.026466
# 5      0.007016  0.009852  0.050     0.107008  -0.006201 -0.026454
# 6      0.007016  0.009852  0.050     0.107008  -0.006192 -0.026445
# 7      0.007016  0.009852  0.050     0.107008  -0.006194 -0.026448
# 8      0.007016  0.009852  0.050     0.107008  -0.006203 -0.026456
# 9      0.007016  0.009852  0.050     0.107008  -0.006199 -0.026452
# 10     0.007016  0.009852  0.050     0.107008  -0.006201 -0.026455
# 11     0.007016  0.009852  0.050     0.107008  -0.006205 -0.026458
# 12     0.007016  0.009852  0.050     0.107008  -0.006195 -0.026448
# 13     0.007016  0.009852  0.050     0.107008  -0.006196 -0.026449
# 14     0.007016  0.009852  0.050     0.107008  -0.006200 -0.026453
# 15     0.007016  0.009852  0.050     0.107008  -0.006210 -0.026463
# 16     0.007016  0.009852  0.050     0.107008  -0.006197 -0.026450
# 17     0.007016  0.009852  0.050     0.107008  -0.006192 -0.026445
# 18     0.007016  0.009852  0.050     0.107008  -0.006208 -0.026461
# 19     0.007016  0.009852  0.050     0.107008  -0.006186 -0.026439
# 20     0.007016  0.009852  0.050     0.107008  -0.006209 -0.026462
# 21     0.007016  0.009852  0.050     0.107008  -0.006198 -0.026451
# 22     0.007016  0.009852  0.050     0.107008  -0.006186 -0.026439
# 23     0.007016  0.009852  0.050     0.107008  -0.006197 -0.026450
# 24     0.007016  0.009852  0.050     0.107008  -0.006195 -0.026448
# 25     0.007016  0.009852  0.050     0.107008  -0.006201 -0.026454
# 26     0.007016  0.009852  0.050     0.107008  -0.006199 -0.026452
# 27     0.007016  0.009852  0.050     0.107008  -0.006198 -0.026451
# 28     0.007016  0.009852  0.050     0.107008  -0.006185 -0.026438
# 29     0.007016  0.009852  0.050     0.107008  -0.006203 -0.026456
# ...         ...       ...    ...          ...        ...       ...
# 50370  0.057745  0.059472  0.975     0.003045  -0.536714 -0.535420
# 50371  0.057745  0.059472  0.975     0.003045  -0.540558 -0.539265
# 50372  0.057745  0.059472  0.975     0.003045  -0.513372 -0.512078
# 50373  0.057745  0.059472  0.975     0.003045  -0.532292 -0.530998
# 50374  0.057745  0.059472  0.975     0.003045  -0.532423 -0.531130
# 50375  0.057745  0.059472  0.975     0.003045  -0.524516 -0.523222
# 50376  0.057745  0.059472  0.975     0.003045  -0.522513 -0.521220
# 50377  0.057745  0.059472  0.975     0.003045  -0.512272 -0.510978
# 50378  0.057745  0.059472  0.975     0.003045  -0.529529 -0.528235
# 50379  0.057745  0.059472  0.975     0.003045  -0.509735 -0.508441
# 50380  0.057745  0.059472  0.975     0.003045  -0.531765 -0.530472
# 50381  0.057745  0.059472  0.975     0.003045  -0.512872 -0.511579
# 50382  0.057745  0.059472  0.975     0.003045  -0.558114 -0.556820
# 50383  0.057745  0.059472  0.975     0.003045  -0.550185 -0.548892
# 50384  0.057745  0.059472  0.975     0.003045  -0.536057 -0.534763
# 50385  0.057745  0.059472  0.975     0.003045  -0.530307 -0.529014
# 50386  0.057745  0.059472  0.975     0.003045  -0.551334 -0.550041
# 50387  0.057745  0.059472  0.975     0.003045  -0.544051 -0.542758
# 50388  0.057745  0.059472  0.975     0.003045  -0.522994 -0.521700
# 50389  0.057745  0.059472  0.975     0.003045  -0.516653 -0.515360
# 50390  0.057745  0.059472  0.975     0.003045  -0.507794 -0.506500
# 50391  0.057745  0.059472  0.975     0.003045  -0.515553 -0.514260
# 50392  0.057745  0.059472  0.975     0.003045  -0.527632 -0.526339
# 50393  0.057745  0.059472  0.975     0.003045  -0.545447 -0.544153
# 50394  0.057745  0.059472  0.975     0.003045  -0.539681 -0.538388
# 50395  0.057745  0.059472  0.975     0.003045  -0.505519 -0.504225
# 50396  0.057745  0.059472  0.975     0.003045  -0.530305 -0.529012
# 50397  0.057745  0.059472  0.975     0.003045  -0.548245 -0.546951
# 50398  0.057745  0.059472  0.975     0.003045  -0.512501 -0.511208
# 50399  0.057745  0.059472  0.975     0.003045  -0.503104 -0.501811
#
#        series_term_Qqi
# 0            -0.000662
# 1            -0.000662
# 2            -0.000664
# 3            -0.000662
# 4            -0.000665
# 5            -0.000664
# 6            -0.000663
# 7            -0.000663
# 8            -0.000664
# 9            -0.000663
# 10           -0.000664
# 11           -0.000664
# 12           -0.000663
# 13           -0.000663
# 14           -0.000663
# 15           -0.000665
# 16           -0.000663
# 17           -0.000663
# 18           -0.000664
# 19           -0.000662
# 20           -0.000664
# 21           -0.000663
# 22           -0.000662
# 23           -0.000663
# 24           -0.000663
# 25           -0.000664
# 26           -0.000663
# 27           -0.000663
# 28           -0.000662
# 29           -0.000664
# ...                ...
# 50370        -0.001634
# 50371        -0.001646
# 50372        -0.001563
# 50373        -0.001621
# 50374        -0.001621
# 50375        -0.001597
# 50376        -0.001591
# 50377        -0.001560
# 50378        -0.001612
# 50379        -0.001552
# 50380        -0.001619
# 50381        -0.001562
# 50382        -0.001699
# 50383        -0.001675
# 50384        -0.001632
# 50385        -0.001615
# 50386        -0.001679
# 50387        -0.001657
# 50388        -0.001593
# 50389        -0.001573
# 50390        -0.001546
# 50391        -0.001570
# 50392        -0.001607
# 50393        -0.001661
# 50394        -0.001643
# 50395        -0.001539
# 50396        -0.001615
# 50397        -0.001669
# 50398        -0.001561
# 50399        -0.001532
#
# [50400 rows x 29 columns]

# %%
# merged.sort_values(by = 'series_term_Qqi', ascending = False)

# Revise... ydiff/s2, and s0, should they have a constant value for all the qs? Tey don't...
# It means... should they have a certain value for each i?
# result = merged.groupby(['dist', 's', 'Q', t0var, 'i']).agg({'series_term_Qqi': 'sum', 'ydiff/s2': ['mean', 'first'], 'var_diff_t0/s2': 'mean'}).rename(columns = {'series_term_Qqi': 'series_term_Qq'})

result = merged.groupby(['dist', 's', 'Q', t0var, 'i']).agg({'series_term_Qqi': 'sum', 'ydiff/s2': 'median', 's0': 'median'}).rename(columns = {'series_term_Qqi': 'series_term_Qq'})
result['Series_sum'] = result.series_term_Qq/result.index.get_level_values('Q') + result.s0

# %%
plt.figure(figsize = (30, 10))
result['Series_sum'].plot(marker = '.', alpha = .2, label = 'Series')
(result['ydiff/s2']).plot(marker = '.', alpha = .2, label = 'Y')
result['s0'].plot(alpha = .2, lw = 0, marker = '.', label = 'Y0')

vals = result.groupby(level = [0, 1]).count().iloc[:, 0].cumsum().values
[plt.axvline(x)for x in vals]
plt.legend()
plt.yscale('log')
plt.show()

# %%
result.loc['norm'].loc[.1].sample(10).sort_index()
# Out:
#                series_term_Qq  ydiff/s2        s0  Series_sum  o1_series
# Q  tdiff0 i
# 10 0.0265 129       -0.012920  0.008599  0.008788    0.007496  -0.001292
#           205       -0.012920  0.008892  0.008788    0.007496  -0.001292
#           266       -0.012909  0.009594  0.008788    0.007497  -0.001291
#           359       -0.012959  0.009231  0.008788    0.007492  -0.001296
#           435       -0.012876  0.009634  0.008788    0.007501  -0.001288
#           479       -0.012957  0.008414  0.008788    0.007493  -0.001296
#    0.3644 243       -0.210082  0.020564  0.040221    0.019213  -0.021008
# 20 0.0265 247       -0.008346  0.007052  0.006348    0.005931  -0.000417
#    0.3644 7         -0.154691  0.013849  0.020807    0.013072  -0.007735
#           241       -0.154715  0.014127  0.020807    0.013071  -0.007736

# %%
result['o1_series'] = result.Series_sum - result.s0
result['solution'] = result['ydiff/s2'] - result.s0

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
plt.figure(figsize = (30, 10))
result.reset_index()['o1_series'].plot(marker = '.', alpha = .2)
result.reset_index()['solution'].plot(marker = '.', alpha = .1)

vals = result.groupby(level = [0, 1]).count().iloc[:, 0].cumsum().values
[plt.axvline(x)for x in vals]
# ply.xlim()
# plt.ylim(-.1, .1)
plt.show()

# %%
result['error'] = (result.Series_sum -  result.y)
result['solution'] = (result.y - result.s0)

plt.figure(figsize = (30, 10))
result.reset_index()['Series_sum'].plot(marker = '.', alpha = .2)
result.reset_index()['solution'].plot(marker = '.', alpha = .2)

vals = result.groupby(level = [0, 1]).count().iloc[:, 0].cumsum().values
[plt.axvline(x)for x in vals]
# ply.xlim()
plt.ylim(-.1, .1)
# Out:
#                         series_term_Qq         y        s0  Series_sum  \
# dist s   Q  x0     i
# lapl 0.1 10 0.1600 0         -0.049124  0.032173  0.037027    0.032114
#                    1         -0.036476  0.035190  0.037027    0.033379
#                    2         -0.042663  0.034289  0.037027    0.032760
#                    3         -0.058102  0.030969  0.037027    0.031217
#                    4         -0.042951  0.035480  0.037027    0.032732
#                    5         -0.044617  0.032081  0.037027    0.032565
#                    6         -0.007460  0.030782  0.037027    0.036281
#                    7         -0.052357  0.032988  0.037027    0.031791
#                    8         -0.058352  0.029561  0.037027    0.031192
#                    9         -0.011645  0.038264  0.037027    0.035862
#                    10        -0.046463  0.032218  0.037027    0.032380
#                    11        -0.049516  0.033646  0.037027    0.032075
#                    12        -0.048999  0.032570  0.037027    0.032127
#                    13        -0.004257  0.031829  0.037027    0.036601
#                    14        -0.008289  0.036514  0.037027    0.036198
#                    15        -0.046647  0.033888  0.037027    0.032362
#                    16        -0.058837  0.029370  0.037027    0.031143
#                    17        -0.053329  0.033004  0.037027    0.031694
#                    18        -0.027145  0.032948  0.037027    0.034312
#                    19        -0.049423  0.031958  0.037027    0.032084
#                    20        -0.054767  0.032446  0.037027    0.031550
#                    21        -0.048049  0.031122  0.037027    0.032222
#                    22        -0.044304  0.029778  0.037027    0.032596
#                    23        -0.024219  0.036016  0.037027    0.034605
#                    24        -0.044964  0.035896  0.037027    0.032530
#                    25        -0.031394  0.032266  0.037027    0.033887
#                    26        -0.044617  0.033067  0.037027    0.032565
#                    27        -0.041280  0.031793  0.037027    0.032899
#                    28        -0.049721  0.033166  0.037027    0.032055
#                    29        -0.044176  0.032988  0.037027    0.032609
# ...                                ...       ...       ...         ...
# norm 0.5 25 1.6832 470       -0.639514  1.128907  1.156579    1.092627
#                    471       -0.614970  1.130113  1.156579    1.095082
#                    472       -0.571972  1.135914  1.156579    1.099381
#                    473       -0.567226  1.133309  1.156579    1.099856
#                    474       -0.614119  1.134686  1.156579    1.095167
#                    475       -0.580521  1.133970  1.156579    1.098526
#                    476       -0.557896  1.134672  1.156579    1.100789
#                    477       -0.600720  1.134385  1.156579    1.096507
#                    478       -0.576919  1.130147  1.156579    1.098887
#                    479       -0.603209  1.136715  1.156579    1.096258
#                    480       -0.478638  1.139844  1.156579    1.108715
#                    481       -0.601915  1.131626  1.156579    1.096387
#                    482       -0.611325  1.130347  1.156579    1.095446
#                    483       -0.565658  1.136890  1.156579    1.100013
#                    484       -0.549759  1.132161  1.156579    1.101603
#                    485       -0.557634  1.130975  1.156579    1.100815
#                    486       -0.572351  1.135344  1.156579    1.099343
#                    487       -0.619022  1.134942  1.156579    1.094676
#                    488       -0.606301  1.129264  1.156579    1.095948
#                    489       -0.532453  1.135342  1.156579    1.103333
#                    490       -0.555819  1.134740  1.156579    1.100997
#                    491       -0.570892  1.135390  1.156579    1.099489
#                    492       -0.559211  1.136805  1.156579    1.100657
#                    493       -0.561718  1.134543  1.156579    1.100407
#                    494       -0.557046  1.136049  1.156579    1.100874
#                    495       -0.587875  1.133723  1.156579    1.097791
#                    496       -0.579616  1.132268  1.156579    1.098617
#                    497       -0.635021  1.129317  1.156579    1.093077
#                    498       -0.531626  1.137862  1.156579    1.103416
#                    499       -0.623420  1.136002  1.156579    1.094237
#
#                            error  solution
# dist s   Q  x0     i
# lapl 0.1 10 0.1600 0   -0.000058 -0.004854
#                    1   -0.001811 -0.001837
#                    2   -0.001529 -0.002738
#                    3    0.000248 -0.006058
#                    4   -0.002749 -0.001547
#                    5    0.000484 -0.004946
#                    6    0.005498 -0.006244
#                    7   -0.001197 -0.004038
#                    8    0.001631 -0.007466
#                    9   -0.002402  0.001237
#                    10   0.000162 -0.004809
#                    11  -0.001571 -0.003380
#                    12  -0.000443 -0.004457
#                    13   0.004772 -0.005198
#                    14  -0.000317 -0.000512
#                    15  -0.001526 -0.003139
#                    16   0.001773 -0.007656
#                    17  -0.001311 -0.004022
#                    18   0.001364 -0.004078
#                    19   0.000126 -0.005069
#                    20  -0.000896 -0.004581
#                    21   0.001100 -0.005905
#                    22   0.002818 -0.007249
#                    23  -0.001411 -0.001010
#                    24  -0.003366 -0.001130
#                    25   0.001622 -0.004761
#                    26  -0.000502 -0.003959
#                    27   0.001106 -0.005234
#                    28  -0.001111 -0.003861
#                    29  -0.000379 -0.004039
# ...                          ...       ...
# norm 0.5 25 1.6832 470 -0.036279 -0.027672
#                    471 -0.035031 -0.026466
#                    472 -0.036532 -0.020665
#                    473 -0.033453 -0.023270
#                    474 -0.039520 -0.021892
#                    475 -0.035443 -0.022609
#                    476 -0.033883 -0.021906
#                    477 -0.037878 -0.022194
#                    478 -0.031261 -0.026431
#                    479 -0.040457 -0.019864
#                    480 -0.031129 -0.016735
#                    481 -0.035238 -0.024953
#                    482 -0.034900 -0.026232
#                    483 -0.036877 -0.019689
#                    484 -0.030558 -0.024417
#                    485 -0.030160 -0.025604
#                    486 -0.036000 -0.021235
#                    487 -0.040265 -0.021637
#                    488 -0.033315 -0.027315
#                    489 -0.032008 -0.021237
#                    490 -0.033743 -0.021839
#                    491 -0.035901 -0.021188
#                    492 -0.036148 -0.019774
#                    493 -0.034137 -0.022035
#                    494 -0.035175 -0.020530
#                    495 -0.035931 -0.022856
#                    496 -0.033651 -0.024311
#                    497 -0.036240 -0.027262
#                    498 -0.034446 -0.018716
#                    499 -0.041765 -0.020577
#
# [158000 rows x 6 columns]

# %%
s_ = .4


for i, Q_ in enumerate([10, 15, 25]):
    y0 = aQ[i] * x0_
    df_ = describe.loc[(describe.dist == 'norm') & (describe.Q == Q_)]
    
    slice_ = df_xy.loc[(df_xy.s == s_) & (df_xy.dist == 'norm') & (df_xy.Q == Q_) & (df_xy.x0 == x0_)]
#     slice_ = slice_.reset_index()
    part_dev_x0 = df_.set_index(['dist', 'Q' , 's', 'q','pct'])['part_dev_x0']['50%'].reset_index().rename(columns = {'50%': 'part_dev_x0'})
# debug. See var_y values for all the i experiments.
# slice_.groupby('i')['y'].describe()[['25%','50%','75%']].plot()
    slice_ = slice_.merge(part_dev_x0)
    slice_['xqi - x0'] = slice_['var_qi'] - slice_['x0']
    slice_['y0'] = y0
    slice_['(x-x0)dy/dx'] = slice_['part_dev_x0']*slice_['xqi - x0']
    slice_ = slice_.sort_values(by = ['i', 'q'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-213-92792b827cc4> in <module>()
#       4 for i, Q_ in enumerate([10, 15, 25]):
#       5     y0 = aQ[i] * x0_
# ----> 6     df_ = describe.loc[(describe.dist == 'norm') & (describe.Q == Q_)]
#       7
#       8     slice_ = df_xy.loc[(df_xy.s == s_) & (df_xy.dist == 'norm') & (df_xy.Q == Q_) & (df_xy.x0 == x0_)]
#
# ~/anaconda2/envs/my_pymc_env/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'dist'

# %%
y0 = s0
# Out:
#                         75%      mean       25%
# dist s   x0
# lapl 0.1 0.030000  0.010215  0.008583  0.006944
#          0.160000  0.032680  0.028579  0.023269
#          0.290000  0.060390  0.049042  0.032205
#          0.420000  0.060535  0.049032  0.037802
#          0.560000  0.067746  0.055208  0.046378
#          0.690000  0.076324  0.071641  0.057399
#          0.820000  0.094036  0.073214  0.035371
#          0.950000  0.115850  0.088907  0.073706
#          1.090000  0.150870  0.136282  0.099195
#          1.220000  0.128637  0.106045  0.058922
#      0.2 0.042500  0.017907  0.015352  0.012971
#          0.190000  0.091154  0.080754  0.067369
#          0.337500  0.134698  0.124425  0.111777
#          0.485000  0.221264  0.203118  0.183681
#          0.632500  0.248966  0.217625  0.190985
#          0.780000  0.285437  0.269337  0.255216
#          0.927500  0.300980  0.274043  0.246703
#          1.075000  0.331342  0.262894  0.203594
#          1.220000  0.402383  0.327244  0.256929
#          1.367500  0.330183  0.288451  0.222165
#      0.3 0.068889  0.037995  0.035338  0.030452
#          0.251111  0.145456  0.130905  0.112195
#          0.433333  0.273566  0.241499  0.214369
#          0.616667  0.403135  0.370442  0.346674
#          0.798889  0.495769  0.485681  0.468689
#          0.981111  0.552787  0.530524  0.501418
#          1.163333  0.666934  0.603063  0.563735
#          1.345556  0.813281  0.726354  0.632931
#          1.527778  0.775887  0.717912  0.664726
#          1.711111  0.828534  0.775197  0.712096
# ...                     ...       ...       ...
# norm 0.3 0.078889  0.041566  0.037684  0.031776
#          0.212222  0.134583  0.119270  0.097769
#          0.344444  0.185032  0.172871  0.154889
#          0.477778  0.264530  0.239744  0.213500
#          0.610000  0.339504  0.330711  0.322812
#          0.742222  0.346003  0.322279  0.279671
#          0.875556  0.481222  0.414377  0.348027
#          1.007778  0.475940  0.431795  0.386611
#          1.141111  0.580083  0.546217  0.519033
#          1.273333  0.515190  0.493782  0.476785
#      0.4 0.089375  0.063399  0.056988  0.048170
#          0.246250  0.141461  0.137716  0.125741
#          0.403750  0.292620  0.279986  0.261040
#          0.560625  0.389172  0.380389  0.364877
#          0.718125  0.487282  0.463089  0.440119
#          0.875000  0.616229  0.605712  0.574489
#          1.032500  0.707732  0.688557  0.662762
#          1.189375  0.720188  0.686862  0.674359
#          1.346875  0.845027  0.817053  0.763273
#          1.503750  0.827391  0.760726  0.692954
#      0.5 0.133600  0.103465  0.093261  0.083881
#          0.305600  0.205370  0.190888  0.167333
#          0.478000  0.330978  0.319869  0.309480
#          0.650000  0.489299  0.463511  0.437864
#          0.822400  0.653510  0.628001  0.595147
#          0.994400  0.861220  0.840161  0.801022
#          1.166800  1.013114  0.966662  0.934097
#          1.338800  1.080705  1.055401  1.024682
#          1.511200  1.161487  1.135277  1.088630
#          1.683200  1.190216  1.153330  1.134120
#
# [100 rows x 3 columns]

# %%
grouped = slice_.groupby('i')
series_approx = grouped['(x-x0)dy/dx'].sum() + grouped['y0'].first()
eval_series = grouped[['y']].quantile(.5)
eval_series['series_y'] = series_approx

eval_series.plot('y', 'series_y', marker = '.', lw = 0, alpha = .1)
# plt.xlim(0, 0.01)
# plt.ylim(0, 0.03)

# %%
# oo are similar/equal for parabola or linear fits, as they should
# fits1['b2'] = fits2['c']
# fits1.plot('b2', 'b', marker = '.', lw = 0)

df_ = fits1.set_index('Q')[['q', 'x0', 'b']]

# df_['x0_'] = df_['x0'] + np.random.uniform(-0.0003, 0.0003, len(df_))

fig, ax = plt.subplots(1, figsize = (7, 5))
df_.loc[10].plot('x0', 'b', marker = '.', lw = 0, ax = ax)
df_.loc[15].plot('x0', 'b', marker = '.', lw = 0, ax = ax)
ax.set_xlim(0, 0.025)
ax.set_ylim(0, 0.015)
plt.show()

# %%
for Q in [10, 15]:
    x = df_.loc[Q]['x0']
    y = df_.loc[Q]['b']
    z = np.polyfit(x, y, 1)
    print(z)
# Out:
# [ 6.11258560e-01 -2.07949449e-04]
# [ 5.66583178e-01 -3.52119285e-04]

# %%
def qvars_fits(degree = 1):
    fits = []
    for q in range(Q_):
        df_xy_q = df_xy.loc[df_xy.q == q]
        # points
        x = df_xy_q.var_qi
        y = df_xy_q.y
        # fit
        z = np.polyfit(x, y, degree)
        fits += [z]
    fits = np.array(fits)
    return fits

# %%
qvars_fits(1)
# Out:
# array([[0.05847141, 0.00347405],
#        [0.05443393, 0.00193246],
#        [0.0560431 , 0.00236648],
#        [0.04881516, 0.00201882],
#        [0.05625421, 0.00229512],
#        [0.06245085, 0.00383869],
#        [0.04270722, 0.00239089],
#        [0.03508963, 0.00175195],
#        [0.03251947, 0.00206818],
#        [0.03632867, 0.00237791]])

# %%
# low var values
df_mp_Q['var_qi'].groupby('q').max().sum()/(Q_**2)
# Out:
# 0.0006697514151924629

# %%
df_xy.sort_values(by = ['q', 'var_qi']).reset_index(drop = True)[['var_qi','y']].plot(marker = '.', alpha = .2)
# plt.yscale('log')
plt.ylim(0, 0.02)
# Out:
# (0, 0.02)

# %%
df_xy.sort_values(by = ['q', 'var_qi']).reset_index(drop = True)[['var_qi','y']].plot(marker = '.', alpha = .2)
plt.yscale('log')

# %%
df_xy.sort_values(by = ['q', 'var_qi']).reset_index(drop = True)[['var_qi','y']].plot(marker = '.', alpha = .2)
plt.yscale('log')

# %%
# For all the variables, get the x y's.
# fit poly, get coefficients, store. 
# option to plot.

# %%
def qvars_fits(degree = 1):
    fits = []
    for q in range(Q_):
        df_xy_q = df_xy.loc[df_xy.q == q]
        # points
        x = df_xy_q.var_qi
        y = df_xy_q.y
        # fit
        z = np.polyfit(x, y, degree)
        fits += [z]
    fits = np.array(fits)
    return fits

fig, ax = plt.subplots(1, figsize = (8, 6))

for q in range(Q_)[:-2]:
    df_xy_q = df_xy.loc[df_xy.q == q]
    ax.plot(df_xy_q.var_qi, df_xy_q.y, '.', alpha = .2)
    bin_mean = df_xy_q.groupby(pd.qcut(df_xy_q.var_qi, 10)).mean()
    bin_mean.plot('var_qi', 'y', marker = 'o', ax = ax)

    # ax.set_xlim(min(x), max(x))
    # ax.set_ylim(min(y), max(y))
    ax.set_xlabel('var_q') 
    ax.set_ylabel('var_y')
    
slice_ = result.loc[result.Q == Q_]
slice_['var'] = slice_['var']#*Q_**2
slice_.plot('var_q', 'var', ax = ax)

ax.set_xlim(0, .1)
ax.set_ylim(0, 0.01)
plt.show()
    # Laplace

# %% [markdown]
# ## Partial devs

# %%
def dx2(x, a, b, c):
    return 2 * a * x + b

def dx(x, a, b):
    return a

# %%
partial_devs_1 = np.array([dx(np.median(x), *pars) for pars in qvars_fits(1)])
partial_devs_2 = np.array([dx2(np.median(x), *pars) for pars in qvars_fits(2)])

# %%
plt.plot(range(Q_), partial_devs_1, marker = '.')
# plt.plot(range(Q_), partial_devs_2, marker = '.')
# plt.plot(range(Q_), fits[:, 0], marker = '.')
# plt.plot(range(Q_), fits[:, 1], marker = '.')
# plt.ylim(0, .07)

# %%
# Gaussian
# Out:
# [0.0863967  0.01296385]
# [0.08842814 0.01074267]
# [0.09689284 0.01611861]
# [0.08432123 0.01063715]
# [0.08689185 0.01206402]
# [0.09146881 0.01389333]
# [0.08071326 0.01385786]
# [0.07617694 0.01076438]
# [0.04747966 0.01308357]
# [0.05237573 0.00767953]

# %%
# Out:
# [0.98859968 6.31536187]
# [1.0726746  5.50727238]
# [1.16982095 8.42172979]
# [1.14772977 7.27886601]
# [0.99899666 8.59448406]
# [ 1.11401587 15.97862462]
# [1.3146688  9.78260646]
# [1.07650366 8.68275585]
# [ 1.18007377 12.5288997 ]
# [ 1.09623537 11.0625377 ]

# %%
fig, ax = plt.subplots(1)

df_xy_q.plot('var_qi', 'y', marker = '.', lw = 0, ax = ax)
bin_mean = df_xy_q.groupby(pd.qcut(df_xy_q.var_qi, 10)).mean()
bin_mean.plot('var_qi', 'y', marker = 'o', ax = ax)

# %% [markdown]
# ## Test at sigma = 0
# What if the sigma_0 point is set at zero? what are the dependencies?
#
# What happens with Q and the total? The curvature of the log should have an effect

# %%
tot_size = 1e11
M = 50000

result_list = []
for Q in [2, 3, 4, 5, 7, 10, 15, 20, 25, 30]:
    v = []
    for var in np.arange(0, 0.005, 0.0001):
        q_size = np.log10(tot_size/Q)
#         sim_q_size_lin = np.power(10, q_size + np.random.laplace(0, np.sqrt(var), M)/np.sqrt(2))
        sim_q_size_lin = np.power(10, q_size + np.random.normal(0, np.sqrt(var), M))
        sim_log_totals = np.log10(sim_q_size_lin + (1 - 1/Q)*tot_size)
        v += [[var, sim_log_totals.var()]]

    result = pd.DataFrame(np.array(v), columns = ['var_q', 'var'])
    result['Q'] = Q
    result_list += [result]
    
result = pd.concat(result_list)

# %%
plt.hist(sim_log_totals, 50)
plt.show()

# %%
fig, ax = plt.subplots(1, figsize = (6, 5))

for Q in result.Q.unique()[:10]:
    slice_ = result.loc[result.Q == Q]
    slice_['var'] = Q**2*slice_['var']
    slice_.plot('var_q', 'var', ax = ax)

# %%
(slice_['var']/slice_['var_q']).plot()
