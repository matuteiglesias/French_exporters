# %% [markdown]
# ### Set up

# %%
#Import modules

import pandas as pd
pd.options.display.max_columns = 99
pd.options.display.max_rows = 999
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

# from numpy import arange, log10

import matplotlib.pyplot as plt
# %matplotlib inline

from numpy import arange, log10
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## Load mu coeffs and use

# %%
CN_full = pd.read_csv('./../data/CN_full.csv', encoding = 'utf-8')
df = pd.read_csv('./../data/processed/mu_FE_decomposition.csv')

# %%
#Large countries
large_countries = df.groupby('PYOD')['VART'].sum().sort_values().tail(10).index

# %%
# Main products
df.groupby(['CN ID 4'])['VART'].sum().sort_values().tail(30).index
# Out:
# Int64Index([8536, 8431, 6110, 8481, 8414, 6204, 8544, 4011, 4202, 8443, 8413,
#             9403, 9401, 9021, 7403, 8802, 8409, 8542, 6403, 8517, 3004, 8704,
#             8411, 8471, 8803, 8708, 2710, 8703, 2711, 2709],
#            dtype='int64', name=u'CN ID 4')

# %%
main_prods = [8409, 6403, 8517, 3004, 8411, 8704, 8471, 8803, 8802, 8708, 2710, 8703, 2711, 2709]
CN_full[['CN ID 4', 'CN label 4']].drop_duplicates().loc[CN_full['CN ID 4'].isin(main_prods)]
# Out:
#        CN ID 4                                         CN label 4
# 4067      2709  Petroleum oils and oils obtained from bitumino...
# 4070      2710  Petroleum oils and oils obtained from bitumino...
# 4142      2711     Petroleum gases and other gaseous hydrocarbons
# 5253      3004  Medicaments (excluding goods of heading 3002, ...
# 9013      6403  Footwear with outer soles of rubber, plastics,...
# 11267     8409  Parts suitable for use solely or principally w...
# 11278     8411  Turbojets, turbopropellers and other gas turbines
# 12213     8471  Automatic data-processing machines and units t...
# 12728     8517  Telephone sets, including telephones for cellu...
# 13339     8703  Motor cars and other motor vehicles principall...
# 13375     8704          Motor vehicles for the transport of goods
# 13437     8708  Parts and accessories of the motor vehicles of...
# 13608     8802  Other aircraft (for example, helicopters, aero...
# 13618     8803             Parts of goods of heading 8801 or 8802

# %% [markdown]
# ### France maps

# %%
#firm sizes
firm_size = df.groupby(['ID', 'YEAR'])[['VART']].sum().reset_index()
firm_size['log_M_size'] = log10(firm_size['VART'])
firm_size = firm_size.groupby(['ID'])[['log_M_size']].mean().reset_index()

#merge with mu FC coeffs
mu_coeffs = df[['ID', 'PYOD', 'mu_fc']].drop_duplicates().merge(firm_size)
mu_coeffs['log_size_bin'] = pd.cut(mu_coeffs['log_M_size'], arange(3, 12))

#load SIREN data
SIREN = pd.read_csv('./../data/SIREN.csv', ';', encoding = 'latin-1')
SIREN = SIREN[['SIREN', 'CODPOS', 'RPET', 'LIBREG','DEPET', 'COMET', 'LIBCOM', 'L6_NORMALISEE', 'L4_NORMALISEE', 'L1_NORMALISEE', 'DDEBACT']]#.sample(5)

# %%
merged = mu_coeffs.merge(SIREN, left_on = 'ID', right_on = 'SIREN', how = 'left').dropna()

# bad merging levels... 
# merged.groupby(['log_size_bin', '_merge']).count()

# %%
# geo info from
# https://www.data.gouv.fr/fr/datasets/contours-des-departements-francais-issus-d-openstreetmap/

import geopandas as gpd

gdf = gpd.read_file('./../data/Geographic/departements-20140306-50m.shp').iloc[:-5]
# Out:
# WARNING:Fiona:Failed to decode fr:Ain (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Aisne (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Allier (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode Ard�che using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Ard�che (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Ardennes (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode Ari�ge using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Ari�ge (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Aube (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Aude (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Aveyron (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode Bouches-du-Rh�ne using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Bouches-du-Rh�ne using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Calvados (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Cantal (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Charente (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Cher (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode Corr�ze using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Corr�ze (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode C�te-d'Or using utf-8 codec
# WARNING:Fiona:Failed to decode fr:C�te-d'Or using utf-8 codec
# WARNING:Fiona:Failed to decode C�tes-d'Armor using utf-8 codec
# WARNING:Fiona:Failed to decode fr:C�tes-d'Armor using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Creuse (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Dordogne (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Doubs (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode Dr�me using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Dr�me (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Eure (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode Finist�re using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Finist�re using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Gers (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Gironde (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode H�rault using utf-8 codec
# WARNING:Fiona:Failed to decode fr:H�rault (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Indre (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode Is�re using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Is�re (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Jura (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Landes (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Loire (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Loiret (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Lot (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode Loz�re using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Loz�re (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Manche (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Marne (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Mayenne (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Meuse (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Moselle (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode Ni�vre using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Ni�vre (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Nord (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Oise (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Orne (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode Puy-de-D�me using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Puy-de-D�me using utf-8 codec
# WARNING:Fiona:Failed to decode Pyr�n�es-Atlantiques using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Pyr�n�es-Atlantiques using utf-8 codec
# WARNING:Fiona:Failed to decode Hautes-Pyr�n�es using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Hautes-Pyr�n�es using utf-8 codec
# WARNING:Fiona:Failed to decode Pyr�n�es-Orientales using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Pyr�n�es-Orientales using utf-8 codec
# WARNING:Fiona:Failed to decode Rh�ne using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Rh�ne (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode Haute-Sa�ne using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Haute-Sa�ne using utf-8 codec
# WARNING:Fiona:Failed to decode Sa�ne-et-Loire using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Sa�ne-et-Loire using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Sarthe (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Savoie (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode Deux-S�vres using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Deux-S�vres using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Somme (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Tarn (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Var (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Vaucluse (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode Vend�e using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Vend�e (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Vienne (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Vosges (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Yonne (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode fr:Essonne (d�partement) using utf-8 codec
# WARNING:Fiona:Failed to decode La R�union using utf-8 codec
# WARNING:Fiona:Failed to decode fr:La R�union using utf-8 codec

# %%
values = merged.groupby(['PYOD', 'log_size_bin', 'DEPET']).agg({'mu_fc': ['mean', 'std', 'count']})['mu_fc']
values = values.loc[['GB', 'BE', 'NL', 'DE', 'CH', 'IT', 'ES', 'CN', 'US']].reset_index()

# %%
# from numpy import mean
EU = gpd.read_file('./../data/Geographic/Europe.shp').set_index('NAME')

# %%
EU
# Out:
#                                                      ORGN_NAME  \
# NAME
# Albania                                              Shqipëria
# Andorra                                                Andorra
# Austria                                             Österreich
# Belgium                                      België / Belgique
# Bosnia Herzegovina                         Bosna i Hercegovina
# Croatia                                               Hrvatska
# Czech Republic                                           Cesko
# Denmark                                                Danmark
# Estonia                                                  Eesti
# Finland                                                  Suomi
# France                                                  France
# Germany                                            Deutschland
# Gibraltar (UK)                                  Gibraltar (UK)
# Greece                                                  Elláda
# Guernsey (UK)                                    Guernsey (UK)
# Hungary                                           Magyarország
# Ireland                                         Éire / Ireland
# Isle of Man (UK)                              Isle of Man (UK)
# Italy                                                   Italia
# Jersey (UK)                                        Jersey (UK)
# Latvia                                                 Latvija
# Liechtenstein                                    Liechtenstein
# Lithuania                                              Lietuva
# Luxembourg                 Lëtzebuerg / Luxemburg / Luxembourg
# Macedonia                                           Makedonija
# Malta                                                    Malta
# Monaco                                                  Monaco
# Montenegro                                           Crna Gora
# Netherlands                                          Nederland
# Norway                                                   Norge
# Poland                                                  Polska
# Portugal                                              Portugal
# San Marino                                          San Marino
# Serbia                                                  Srbija
# Slovakia                                             Slovensko
# Slovenia                                             Slovenija
# Spain                                                   España
# Sweden                                                 Sverige
# Switzerland               Schweiz / Suisse / Svizerra / Svizra
# United Kingdom                                  United Kingdom
# Armenia                                               Hayastan
# Azerbaijan                                          Azerbaycan
# Belarus                                                Belarus
# Bulgaria                                             Balgarija
# Faeroe Islands (Denmark)                     Foroyar (Danmark)
# Georgia                                             Sakartvelo
# Iceland                                                 Ísland
# Jan Mayen (Norway)                           Jan Mayen (Norge)
# Moldova                                                Moldova
# Romania                                                România
# Svalbard (Norway)                             Svalbard (Norge)
# Turkey                                                 Türkiye
# Ukraine                                               Ukrajina
# Russia                                                 Rossíya
#
#                                                                    geometry
# NAME
# Albania                   (POLYGON ((19.50115199999999 40.96229600000001...
# Andorra                   POLYGON ((1.439921999999996 42.60649100000001,...
# Austria                   POLYGON ((16 48.77775199999999, 16 48.78252000...
# Belgium                   POLYGON ((5 49.79374300000001, 4.9972390000000...
# Bosnia Herzegovina        POLYGON ((19.22947300000001 43.534584, 19.2292...
# Croatia                   (POLYGON ((14.300375 44.501564, 14.289716 44.5...
# Czech Republic            POLYGON ((14.825232 50.87399300000001, 14.8368...
# Denmark                   (POLYGON ((11.99977999999999 54.94117700000001...
# Estonia                   (POLYGON ((23.97510700000001 58.09690900000001...
# Finland                   (POLYGON ((22.07309900000001 60.228298, 22.065...
# France                    (POLYGON ((-2.281369000000012 46.6856960000000...
# Germany                   (POLYGON ((13.11717200000001 54.54924, 13.1252...
# Gibraltar (UK)            POLYGON ((-5.353221999999988 36.15979799999999...
# Greece                    (POLYGON ((24.742828 37.5956, 24.735344 37.597...
# Guernsey (UK)             (POLYGON ((-2.524833999999998 49.4886700000000...
# Hungary                   POLYGON ((22.32725099999999 48.361942, 22.3229...
# Ireland                   (POLYGON ((-10.21726100000001 51.74543, -10.22...
# Isle of Man (UK)          (POLYGON ((-4.38349199999999 54.32593900000001...
# Italy                     (POLYGON ((12.46117100000001 37.880753, 12.456...
# Jersey (UK)               POLYGON ((-2.035068999999993 49.19904700000001...
# Latvia                    POLYGON ((22.14997099999999 57.64129299999999,...
# Liechtenstein             POLYGON ((9.535913999999991 47.27354, 9.560372...
# Lithuania                 (POLYGON ((26.22030100000001 55, 26.2169320000...
# Luxembourg                POLYGON ((6.138020000000012 50.132904, 6.14091...
# Macedonia                 POLYGON ((22.373819 42.32666800000001, 22.3722...
# Malta                     (POLYGON ((14.33938000000001 36.00751099999999...
# Monaco                    POLYGON ((7.406804999999991 43.73195999999999,...
# Montenegro                (POLYGON ((19.22947300000001 43.534584, 19.227...
# Netherlands               (POLYGON ((6.050385000000006 53.44674699999999...
# Norway                    (POLYGON ((14.824039 68.21676600000001, 14.806...
# Poland                    (POLYGON ((14.21287899999999 53.86478399999999...
# Portugal                  (POLYGON ((-25.83763099999999 37.885948, -25.8...
# San Marino                POLYGON ((12.51003600000001 43.99980500000001,...
# Serbia                    POLYGON ((18.838751 45.90741700000001, 18.8646...
# Slovakia                  POLYGON ((18.85061099999999 49.52130500000001,...
# Slovenia                  POLYGON ((16.56601699999999 46.48371900000001,...
# Spain                     (POLYGON ((-5.609040999999991 36.0003240000000...
# Sweden                    (POLYGON ((16.698172 57.43244200000001, 16.694...
# Switzerland               POLYGON ((9.535913999999991 47.27354, 9.526596...
# United Kingdom            (POLYGON ((-5.335227000000003 51.8583030000000...
# Armenia                   (POLYGON ((45.48184599999999 40.65776099999999...
# Azerbaijan                (POLYGON ((49.02263600000001 39.196472, 49.028...
# Belarus                   POLYGON ((30 51.48946000000001, 29.953135 51.4...
# Bulgaria                  POLYGON ((22.68182899999999 44.217648, 22.6889...
# Faeroe Islands (Denmark)  (POLYGON ((-6.373784999999998 62.2357519999999...
# Georgia                   POLYGON ((40.01023900000001 43.38325900000001,...
# Iceland                   (POLYGON ((-15.387833 64.356842, -15.396913000...
# Jan Mayen (Norway)        POLYGON ((-8.137269000000003 71.146187, -8.094...
# Moldova                   POLYGON ((27.72524300000001 48.45465899999999,...
# Romania                   (POLYGON ((29.594585 44.81385399999999, 29.577...
# Svalbard (Norway)         (POLYGON ((20.802177 78.56455199999999, 20.803...
# Turkey                    (POLYGON ((29.11931799999999 40.83066199999999...
# Ukraine                   (POLYGON ((33.52988400000001 45.87363099999999...
# Russia                    (POLYGON ((52.65437700000001 71.45161400000001...

# %%
EU.loc[[name]]
# Out:
#                  ORGN_NAME                                           geometry
# NAME
# Belgium  België / Belgique  POLYGON ((5 49.79374300000001, 4.9972390000000...

# %%
for j in range(6):
    country = ['BE', 'DE', 'IT', 'ES', 'US', 'CN'][j]
    print country
    
    colormap = ['Oranges', 'Purples', 'Blues', 'Greens', 'PuBu', 'OrRd'][j]
    invals = [pd.Interval(5, 6, closed='right'), pd.Interval(6, 7, closed='right'), pd.Interval(7, 8, closed='right')]
    titles = ['100k/yr to 1M/yr importers', '1M/yr to 10M/yr importers', '10M/yr to 100M/yr importers']
    fig, axs = plt.subplots(1, len(invals), figsize = (18, 5.5))
    for i in range(len(invals)):
        interval = invals[i]
        ax = axs[i]
        sel_values = values.loc[(values.PYOD == country) & (values.log_size_bin == interval) ]
        sel_values = gpd.GeoDataFrame(sel_values.merge(gdf[['code_insee', 'geometry']], left_on = 'DEPET', right_on = 'code_insee', how = 'right'))
        sel_values['mean'] = sel_values['mean'].fillna(sel_values['mean'].median())
        sel_values.plot(column = 'mean', linewidth = 0, cmap = colormap, ax = ax)
        if j< 4: 
            name = ['Belgium', 'Germany', 'Italy', 'Spain'][j]
            EU.loc[[name]].plot(linewidth = 0.5, color = 'w', ax = ax)
        ax.set_xlim(-6, 10); ax.set_ylim(40, 52);
        ax.axis('off')
        ax.set_title(titles[i])
    plt.savefig('./../Figures/firm_country_mu_coeff_'+country+'.png')
    plt.show()
# Out:
# BE
# DE
# IT
# ES
# US
# CN
