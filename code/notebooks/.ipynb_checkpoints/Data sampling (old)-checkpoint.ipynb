# %% [markdown]
# # Data reading and sampling

# %%
import pandas as pd
import numpy as np
import time

# %% [markdown]
# ### Useful functions for chunk filtering and aggregation

# %%
path = './../../../../media/miglesia/Elements/export_france/data/'
path1 = path+'type1/DP1610_MAASTRICHT1_1997_2013'
path2 = path+'type2/DP1611_MAASTRICHT2_1997_2013'

# Writing as a function

def aggregation(chunk, index, func):
    grouped_object = chunk.groupby(index,sort = False)
    # not sorting results in a minor speedup
    return grouped_object.agg(func)
                                
colnames = [u'YEAR', u'MONTH', u'FLUX', u'ID', u'DEPT', u'CN ID 8', u'CPA6',
       u'PYOD', u'PAYP', u'VAT', u'PRIFAC', u'DEVFAC', u'VFTE', u'VART', u'D_MASSE', u'MASSE', u'USUP', u'USUP_MT']

colname_no = dict(zip(colnames, range(18)))
colno_name = dict(zip(range(18), colnames))

#We need to know number of rows of each file:

l = []
with open(path+'/type1_row_ct') as f:
    for line in f:
        l += [int(line.strip())]
nrows1 = dict(zip(range(1997, 2014), l))

l = []
with open(path+'/type2_row_ct') as f:
    for line in f:
        l += [int(line.strip())]
nrows2 = dict(zip(range(1997, 2014), l))

def merge_ref(df, filter_ref, filter_ix):
    return df.reset_index().merge(filter_ref, on = filter_ix, how = 'left').set_index('index')
     
def select_entries(df, filter_col, value, by_df = None):
    if by_df is None:
        by_df = df
        
    if isinstance(value, (list,)):
        return df.loc[by_df[filter_col].isin(value)]
    else:
        return df.loc[by_df[filter_col] == value]

# %% [markdown]
# ### Load and process references for filtering (eg. data on firm sizes to filter by size)

# %%
sizes_index = pd.read_csv('./../export_france/data/formatted/sizes_index.csv')

n_bins = 20

sizes_index['log_exp_mma'] = np.log10(sizes_index.exp_mma).round(3)
cuts = pd.cut(sizes_index.groupby(sizes_index['log_exp_mma']).sum().cumsum()['exp_mma'],n_bins, labels=range(n_bins))
exp_index = sizes_index.merge(cuts.reset_index().rename({'exp_mma': 'exp_mma_cat'}, axis = 1), on = 'log_exp_mma').dropna(subset = ['exp_mma'])

exp_size_ref = exp_index[['ID', 'exp_mma_cat']]; filter_ix = 'ID'; filter_col = 'exp_mma_cat';

# %%
colname_no
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3c1d15157e97> in <module>()
# ----> 1 colname_no
#
# NameError: name 'colname_no' is not defined

# %% [markdown]
# ### Main loop for reading from hard drive and saving

# %%
# names = tuple(index)
# sampling_name = name

years = list(reversed(range(1997, 2014)))
n_chunks = 5
data_path = path+'type1/DP1610_MAASTRICHT1_1997_2013'
columns = ['YEAR', 'MONTH', 'FLUX', 'ID', 'CN ID 8', 'VAT','VART']
aggregate_chunks = True
chunk_agg_func = {'VART':['sum']}
aggregate_years = True
yr_agg_func = {'VART_sum':['sum']}
verbose = True
output_index = ['YEAR', 'MONTH', 'IMPORT', 'ID', 'CN ID 8', 'VAT']

save_yr_agg_result = True
save_path = path1+'/samplings'

for bin_ in list(reversed(range(5))): #n_bins
    print 'bin no. '+str(bin_)
    sampling_name = 'YMxpb_size'+str(n_bins).zfill(2)+str(bin_).zfill(2)
    l = []

    for y in years:
        print 'year: '+str(y)
        #Rows for each chunk
        size = np.ceil(nrows1[y]/n_chunks)
        print 'max_chunk_size: '+str(size)

        reader = pd.read_csv(data_path+'/DP1610_MAASTRICHT1_'+str(y)+'.txt', chunksize = size, 
                             usecols = map(colname_no.get, columns)
                             , delimiter = ';', header = None) #'CN ID 8', 'PYOD'

        yr_result_list = []

        #Loop over chunks
        for i in range(int(n_chunks)):
            start_time = time.time()
            chunk = next(reader).rename(colno_name, axis = 1)
            chunk['IMPORT'] = chunk['FLUX'] % 2 # so that '1' indicates imports

            """
            Chunk filtering
            """
            #select imports/exports
            chunk = select_entries(chunk, filter_col = 'IMPORT', value = 0)

            # select by firm size
            chunk_ = merge_ref(chunk, exp_size_ref, filter_ix = 'ID')
            chunk = select_entries(chunk, filter_col = 'exp_mma_cat', value = bin_, by_df = chunk_)

            """
            Chunk aggregation
            """
            if aggregate_chunks: 
                result_chunk = aggregation(chunk, output_index, chunk_agg_func)
            else: 
                result_chunk = chunk

    #             print result_chunk.head()

            yr_result_list += [result_chunk]
            if verbose: print("Number of rows ",result_chunk.shape[0])
            if verbose: print("Loop ",i,"took %s seconds" % (time.time() - start_time))
            del(result_chunk) 


        concat_result = pd.concat(yr_result_list)
    #         print concat_result.head()

        # Unique users vs Number of rows after the first computation    
        if verbose: print("size of concat_result:", len(concat_result))
    #         if verbose: print("unique firms in concat_result:", len(concat_result.index.unique()))

        result = concat_result
        result.columns = ['_'.join(col).strip() for col in result.columns.values]

        if aggregate_years:
    #             yr_agg_result = result.groupby(index).agg(yr_agg_func)
            yr_agg_result = aggregation(result, output_index, yr_agg_func)
            yr_agg_result.index = pd.MultiIndex.from_tuples(list(yr_agg_result.index), names=tuple(output_index))
            yr_agg_result.columns = yr_agg_result.columns.droplevel(1)

        else:
            yr_agg_result = result

        if verbose: print("size of yr_agg_result:", len(yr_agg_result))

        l += [yr_agg_result]

        if save_yr_agg_result:
            yr_agg_result.to_csv(save_path+'/'+sampling_name+'_'+str(y)+'.csv')

    filename = save_path+'/'+sampling_name+'.csv'
    pd.concat(l).to_csv(filename, index = True)
    print 'saved at: '+str(filename)
# Out:
# bin no. 4
# year: 2013
# max_chunk_size: 8180411.0
# ('Number of rows ', 302642)
# ('Loop ', 0, 'took 13.9477069378 seconds')
# ('Number of rows ', 393928)
# ('Loop ', 1, 'took 14.4318678379 seconds')
# ('Number of rows ', 341081)
# ('Loop ', 2, 'took 13.6467909813 seconds')
# ('Number of rows ', 293679)
# ('Loop ', 3, 'took 13.7152709961 seconds')
# ('Number of rows ', 438088)
# ('Loop ', 4, 'took 15.204102993 seconds')
# ('size of concat_result:', 1769418)
# ('size of yr_agg_result:', 1769418)
# year: 2012
# max_chunk_size: 7662320.0
# ('Number of rows ', 327518)
# ('Loop ', 0, 'took 13.8196032047 seconds')
# ('Number of rows ', 409615)
# ('Loop ', 1, 'took 12.7951090336 seconds')
# ('Number of rows ', 356790)
# ('Loop ', 2, 'took 13.3200321198 seconds')
# ('Number of rows ', 300242)
# ('Loop ', 3, 'took 11.6757600307 seconds')
# ('Number of rows ', 443861)
# ('Loop ', 4, 'took 13.136922121 seconds')
# ('size of concat_result:', 1838026)
# ('size of yr_agg_result:', 1838026)
# year: 2011
# max_chunk_size: 7195973.0
# ('Number of rows ', 329935)
# ('Loop ', 0, 'took 12.0339870453 seconds')
# ('Number of rows ', 412061)
# ('Loop ', 1, 'took 11.9617278576 seconds')
# ('Number of rows ', 367878)
# ('Loop ', 2, 'took 11.936798811 seconds')
# ('Number of rows ', 333353)
# ('Loop ', 3, 'took 11.8032450676 seconds')
# ('Number of rows ', 443877)
# ('Loop ', 4, 'took 12.0782859325 seconds')
# ('size of concat_result:', 1887104)
# ('size of yr_agg_result:', 1887104)
# year: 2010
# max_chunk_size: 6993649.0
# ('Number of rows ', 318639)
# ('Loop ', 0, 'took 12.6183290482 seconds')
# ('Number of rows ', 432627)
# ('Loop ', 1, 'took 12.7147080898 seconds')
# ('Number of rows ', 356639)
# ('Loop ', 2, 'took 12.7117030621 seconds')
# ('Number of rows ', 337937)
# ('Loop ', 3, 'took 11.614082098 seconds')
# ('Number of rows ', 458697)
# ('Loop ', 4, 'took 12.3916378021 seconds')
# ('size of concat_result:', 1904539)
# ('size of yr_agg_result:', 1904539)
# year: 2009
# max_chunk_size: 6278669.0
# ('Number of rows ', 323112)
# ('Loop ', 0, 'took 10.7770211697 seconds')
# ('Number of rows ', 395642)
# ('Loop ', 1, 'took 10.9725039005 seconds')
# ('Number of rows ', 351607)
# ('Loop ', 2, 'took 11.0192620754 seconds')
# ('Number of rows ', 325143)
# ('Loop ', 3, 'took 10.1357550621 seconds')
# ('Number of rows ', 432166)
# ('Loop ', 4, 'took 11.3840408325 seconds')
# ('size of concat_result:', 1827670)
# ('size of yr_agg_result:', 1827670)
# year: 2008
# max_chunk_size: 6309116.0
# ('Number of rows ', 348349)
# ('Loop ', 0, 'took 11.1269631386 seconds')
# ('Number of rows ', 371911)
# ('Loop ', 1, 'took 11.9650540352 seconds')
# ('Number of rows ', 403101)
# ('Loop ', 2, 'took 12.4559371471 seconds')
# ('Number of rows ', 326730)
# ('Loop ', 3, 'took 11.3746831417 seconds')
# ('Number of rows ', 451503)
# ('Loop ', 4, 'took 12.5259389877 seconds')
# ('size of concat_result:', 1901594)
# ('size of yr_agg_result:', 1901594)
# year: 2007
# max_chunk_size: 6160497.0
# ('Number of rows ', 316790)
# ('Loop ', 0, 'took 13.4012131691 seconds')
# ('Number of rows ', 407608)
# ('Loop ', 1, 'took 12.1931509972 seconds')
# ('Number of rows ', 351376)
# ('Loop ', 2, 'took 12.0405380726 seconds')
# ('Number of rows ', 318711)
# ('Loop ', 3, 'took 11.3904690742 seconds')
# ('Number of rows ', 444418)
# ('Loop ', 4, 'took 12.8067948818 seconds')
# ('size of concat_result:', 1838903)
# ('size of yr_agg_result:', 1838903)
# year: 2006
# max_chunk_size: 5789960.0
# ('Number of rows ', 276557)
# ('Loop ', 0, 'took 11.4449188709 seconds')
# ('Number of rows ', 363951)
# ('Loop ', 1, 'took 11.1819610596 seconds')
# ('Number of rows ', 325295)
# ('Loop ', 2, 'took 11.6386890411 seconds')
# ('Number of rows ', 317130)
# ('Loop ', 3, 'took 10.9012269974 seconds')
# ('Number of rows ', 404811)
# ('Loop ', 4, 'took 11.5697219372 seconds')
# ('size of concat_result:', 1687744)
# ('size of yr_agg_result:', 1687744)
# year: 2005
# max_chunk_size: 5559688.0
# ('Number of rows ', 233331)
# ('Loop ', 0, 'took 10.3111281395 seconds')
# ('Number of rows ', 318215)
# ('Loop ', 1, 'took 10.7330999374 seconds')
# ('Number of rows ', 290698)
# ('Loop ', 2, 'took 10.4331109524 seconds')
# ('Number of rows ', 277013)
# ('Loop ', 3, 'took 10.4156620502 seconds')
# ('Number of rows ', 369947)
# ('Loop ', 4, 'took 11.3115620613 seconds')
# ('size of concat_result:', 1489204)
# ('size of yr_agg_result:', 1489204)
# year: 2004
# max_chunk_size: 5218704.0
# ('Number of rows ', 248532)
# ('Loop ', 0, 'took 10.4328539371 seconds')
# ('Number of rows ', 305272)
# ('Loop ', 1, 'took 10.0867381096 seconds')
# ('Number of rows ', 270831)
# ('Loop ', 2, 'took 10.2905631065 seconds')
# ('Number of rows ', 264595)
# ('Loop ', 3, 'took 10.1605591774 seconds')
# ('Number of rows ', 300643)
# ('Loop ', 4, 'took 12.3875908852 seconds')
# ('size of concat_result:', 1389873)
# ('size of yr_agg_result:', 1389873)
# year: 2003
# max_chunk_size: 4899719.0
# ('Number of rows ', 255630)
# ('Loop ', 0, 'took 9.8306479454 seconds')
# ('Number of rows ', 273732)
# ('Loop ', 1, 'took 10.2486979961 seconds')
# ('Number of rows ', 266819)
# ('Loop ', 2, 'took 10.1792390347 seconds')
# ('Number of rows ', 230060)
# ('Loop ', 3, 'took 9.34922409058 seconds')
# ('Number of rows ', 295797)
# ('Loop ', 4, 'took 9.93997812271 seconds')
# ('size of concat_result:', 1322038)
# ('size of yr_agg_result:', 1322038)
# year: 2002
# max_chunk_size: 4739381.0
# ('Number of rows ', 235318)
# ('Loop ', 0, 'took 9.82677221298 seconds')
# ('Number of rows ', 270112)
# ('Loop ', 1, 'took 9.76036500931 seconds')
# ('Number of rows ', 266659)
# ('Loop ', 2, 'took 9.37001490593 seconds')
# ('Number of rows ', 237125)
# ('Loop ', 3, 'took 9.07592511177 seconds')
# ('Number of rows ', 291830)
# ('Loop ', 4, 'took 9.91286182404 seconds')
# ('size of concat_result:', 1301044)
# ('size of yr_agg_result:', 1301044)
# year: 2001
# max_chunk_size: 4634439.0
# ('Number of rows ', 238120)
# ('Loop ', 0, 'took 9.96439599991 seconds')
# ('Number of rows ', 256318)
# ('Loop ', 1, 'took 9.29551696777 seconds')
# ('Number of rows ', 274263)
# ('Loop ', 2, 'took 9.69497895241 seconds')
# ('Number of rows ', 228270)
# ('Loop ', 3, 'took 8.67206692696 seconds')
# ('Number of rows ', 287187)
# ('Loop ', 4, 'took 10.1295468807 seconds')
# ('size of concat_result:', 1284158)
# ('size of yr_agg_result:', 1284158)
# year: 2000
# max_chunk_size: 4608999.0
# ('Number of rows ', 235606)
# ('Loop ', 0, 'took 9.30647516251 seconds')
# ('Number of rows ', 256080)
# ('Loop ', 1, 'took 9.20810699463 seconds')
# ('Number of rows ', 255444)
# ('Loop ', 2, 'took 9.26107215881 seconds')
# ('Number of rows ', 228006)
# ('Loop ', 3, 'took 8.68952512741 seconds')
# ('Number of rows ', 279021)
# ('Loop ', 4, 'took 9.32705307007 seconds')
# ('size of concat_result:', 1254157)
# ('size of yr_agg_result:', 1254157)
# year: 1999
# max_chunk_size: 4400886.0
# ('Number of rows ', 229672)
# ('Loop ', 0, 'took 9.05083799362 seconds')
# ('Number of rows ', 263043)
# ('Loop ', 1, 'took 8.72825479507 seconds')
# ('Number of rows ', 237553)
# ('Loop ', 2, 'took 8.88780283928 seconds')
# ('Number of rows ', 236569)
# ('Loop ', 3, 'took 7.92498111725 seconds')
# ('Number of rows ', 262581)
# ('Loop ', 4, 'took 28.3624939919 seconds')
# ('size of concat_result:', 1229418)
# ('size of yr_agg_result:', 1229418)
# year: 1998
# max_chunk_size: 4181341.0
# ('Number of rows ', 214444)
# ('Loop ', 0, 'took 7.44507098198 seconds')
# ('Number of rows ', 243977)
# ('Loop ', 1, 'took 7.23466897011 seconds')
# ('Number of rows ', 232266)
# ('Loop ', 2, 'took 7.34340691566 seconds')
# ('Number of rows ', 220787)
# ('Loop ', 3, 'took 7.42842411995 seconds')
# ('Number of rows ', 249680)
# ('Loop ', 4, 'took 8.39774703979 seconds')
# ('size of concat_result:', 1161154)
# ('size of yr_agg_result:', 1161154)
# year: 1997
# max_chunk_size: 3860625.0
# ('Number of rows ', 181260)
# ('Loop ', 0, 'took 6.70360684395 seconds')
# ('Number of rows ', 227940)
# ('Loop ', 1, 'took 6.78444385529 seconds')
# ('Number of rows ', 195056)
# ('Loop ', 2, 'took 7.15361881256 seconds')
# ('Number of rows ', 195081)
# ('Loop ', 3, 'took 6.71233201027 seconds')
# ('Number of rows ', 227168)
# ('Loop ', 4, 'took 6.84835410118 seconds')
# ('size of concat_result:', 1026505)
# ('size of yr_agg_result:', 1026505)
# saved at: ./../../../../media/miglesia/Elements/export_france/data/type1/DP1610_MAASTRICHT1_1997_2013/samplings/YMxpb_size2004.csv
# bin no. 3
# year: 2013
# max_chunk_size: 8180411.0
# ('Number of rows ', 267201)
# ('Loop ', 0, 'took 13.7272500992 seconds')
# ('Number of rows ', 343072)
# ('Loop ', 1, 'took 12.6762878895 seconds')
# ('Number of rows ', 288919)
# ('Loop ', 2, 'took 12.9357988834 seconds')
# ('Number of rows ', 245402)
# ('Loop ', 3, 'took 12.6043550968 seconds')
# ('Number of rows ', 372618)
# ('Loop ', 4, 'took 13.4965929985 seconds')
# ('size of concat_result:', 1517212)
# ('size of yr_agg_result:', 1517212)
# year: 2012
# max_chunk_size: 7662320.0
# ('Number of rows ', 270721)
# ('Loop ', 0, 'took 12.0424470901 seconds')
# ('Number of rows ', 340682)
# ('Loop ', 1, 'took 12.0376739502 seconds')
# ('Number of rows ', 290274)
# ('Loop ', 2, 'took 12.3371109962 seconds')
# ('Number of rows ', 246709)
# ('Loop ', 3, 'took 11.332665205 seconds')
# ('Number of rows ', 368031)
# ('Loop ', 4, 'took 12.5590829849 seconds')
# ('size of concat_result:', 1516417)
# ('size of yr_agg_result:', 1516417)
# year: 2011
# max_chunk_size: 7195973.0
# ('Number of rows ', 278175)
# ('Loop ', 0, 'took 11.2788350582 seconds')
# ('Number of rows ', 340164)
# ('Loop ', 1, 'took 11.3182199001 seconds')
# ('Number of rows ', 302931)
# ('Loop ', 2, 'took 11.7510139942 seconds')
# ('Number of rows ', 270344)
# ('Loop ', 3, 'took 10.8120849133 seconds')
# ('Number of rows ', 368040)
# ('Loop ', 4, 'took 11.4093949795 seconds')
# ('size of concat_result:', 1559654)
# ('size of yr_agg_result:', 1559654)
# year: 2010
# max_chunk_size: 6993649.0
# ('Number of rows ', 264484)
# ('Loop ', 0, 'took 11.6926450729 seconds')
# ('Number of rows ', 365248)
# ('Loop ', 1, 'took 13.1544401646 seconds')
# ('Number of rows ', 283536)
# ('Loop ', 2, 'took 12.1003260612 seconds')
# ('Number of rows ', 272148)
# ('Loop ', 3, 'took 10.9837300777 seconds')
# ('Number of rows ', 375104)
# ('Loop ', 4, 'took 11.8111650944 seconds')
# ('size of concat_result:', 1560520)
# ('size of yr_agg_result:', 1560520)
# year: 2009
# max_chunk_size: 6278669.0
# ('Number of rows ', 268386)
# ('Loop ', 0, 'took 10.2598609924 seconds')
# ('Number of rows ', 319434)
# ('Loop ', 1, 'took 10.5645420551 seconds')
# ('Number of rows ', 279617)
# ('Loop ', 2, 'took 10.2514541149 seconds')
# ('Number of rows ', 274940)
# ('Loop ', 3, 'took 9.8309109211 seconds')
# ('Number of rows ', 332609)
# ('Loop ', 4, 'took 10.6702809334 seconds')
# ('size of concat_result:', 1474986)
# ('size of yr_agg_result:', 1474986)
# year: 2008
# max_chunk_size: 6309116.0
# ('Number of rows ', 302509)
# ('Loop ', 0, 'took 10.5696160793 seconds')
# ('Number of rows ', 318684)
# ('Loop ', 1, 'took 14.1679589748 seconds')
# ('Number of rows ', 336197)
# ('Loop ', 2, 'took 10.8097348213 seconds')
# ('Number of rows ', 274989)
# ('Loop ', 3, 'took 10.1111729145 seconds')
# ('Number of rows ', 356950)
# ('Loop ', 4, 'took 10.9352369308 seconds')
# ('size of concat_result:', 1589329)
# ('size of yr_agg_result:', 1589329)
# year: 2007
# max_chunk_size: 6160497.0
# ('Number of rows ', 275541)
# ('Loop ', 0, 'took 10.39534688 seconds')
# ('Number of rows ', 350999)
# ('Loop ', 1, 'took 10.3417928219 seconds')
# ('Number of rows ', 294224)
# ('Loop ', 2, 'took 10.061496973 seconds')
# ('Number of rows ', 282013)
# ('Loop ', 3, 'took 9.8209631443 seconds')
# ('Number of rows ', 371677)
# ('Loop ', 4, 'took 10.6431131363 seconds')
# ('size of concat_result:', 1574454)
# ('size of yr_agg_result:', 1574454)
# year: 2006
# max_chunk_size: 5789960.0
# ('Number of rows ', 267289)
# ('Loop ', 0, 'took 10.3975479603 seconds')
# ('Number of rows ', 341883)
# ('Loop ', 1, 'took 9.97214603424 seconds')
# ('Number of rows ', 291380)
# ('Loop ', 2, 'took 10.2618980408 seconds')
# ('Number of rows ', 300179)
# ('Loop ', 3, 'took 9.57839393616 seconds')
# ('Number of rows ', 351077)
# ('Loop ', 4, 'took 9.91428780556 seconds')
# ('size of concat_result:', 1551808)
# ('size of yr_agg_result:', 1551808)
# year: 2005
# max_chunk_size: 5559688.0
# ('Number of rows ', 259076)
# ('Loop ', 0, 'took 9.05098700523 seconds')
# ('Number of rows ', 337614)
# ('Loop ', 1, 'took 9.39578390121 seconds')
# ('Number of rows ', 291208)
# ('Loop ', 2, 'took 9.18743300438 seconds')
# ('Number of rows ', 283452)
# ('Loop ', 3, 'took 9.13854789734 seconds')
# ('Number of rows ', 350607)
# ('Loop ', 4, 'took 9.53771901131 seconds')
# ('size of concat_result:', 1521957)
# ('size of yr_agg_result:', 1521957)
# year: 2004
# max_chunk_size: 5218704.0
# ('Number of rows ', 247209)
# ('Loop ', 0, 'took 8.63054680824 seconds')
# ('Number of rows ', 316964)
# ('Loop ', 1, 'took 8.79503703117 seconds')
# ('Number of rows ', 272786)
# ('Loop ', 2, 'took 9.02286291122 seconds')
# ('Number of rows ', 281200)
# ('Loop ', 3, 'took 8.75066113472 seconds')
# ('Number of rows ', 324354)
# ('Loop ', 4, 'took 9.14877390862 seconds')
# ('size of concat_result:', 1442513)
# ('size of yr_agg_result:', 1442513)
# year: 2003
# max_chunk_size: 4899719.0
# ('Number of rows ', 240291)
# ('Loop ', 0, 'took 8.18458986282 seconds')
# ('Number of rows ', 284579)
# ('Loop ', 1, 'took 8.24977898598 seconds')
# ('Number of rows ', 278103)
# ('Loop ', 2, 'took 8.67640805244 seconds')
# ('Number of rows ', 238213)
# ('Loop ', 3, 'took 8.3927218914 seconds')
# ('Number of rows ', 321676)
# ('Loop ', 4, 'took 8.48198103905 seconds')
# ('size of concat_result:', 1362862)
# ('size of yr_agg_result:', 1362862)
# year: 2002
# max_chunk_size: 4739381.0
# ('Number of rows ', 226992)
# ('Loop ', 0, 'took 8.28378009796 seconds')
# ('Number of rows ', 279632)
# ('Loop ', 1, 'took 8.33422994614 seconds')
# ('Number of rows ', 263848)
# ('Loop ', 2, 'took 8.17145299911 seconds')
# ('Number of rows ', 220775)
# ('Loop ', 3, 'took 7.78389000893 seconds')
# ('Number of rows ', 312675)
# ('Loop ', 4, 'took 8.6497220993 seconds')
# ('size of concat_result:', 1303922)
# ('size of yr_agg_result:', 1303922)
# year: 2001
# max_chunk_size: 4634439.0
# ('Number of rows ', 223731)
# ('Loop ', 0, 'took 8.10240507126 seconds')
# ('Number of rows ', 260628)
# ('Loop ', 1, 'took 8.34812092781 seconds')
# ('Number of rows ', 273927)
# ('Loop ', 2, 'took 8.12891197205 seconds')
# ('Number of rows ', 216953)
# ('Loop ', 3, 'took 7.73528599739 seconds')
# ('Number of rows ', 306017)
# ('Loop ', 4, 'took 8.03918290138 seconds')
# ('size of concat_result:', 1281256)
# ('size of yr_agg_result:', 1281256)
# year: 2000
# max_chunk_size: 4608999.0
# ('Number of rows ', 218762)
# ('Loop ', 0, 'took 8.17592811584 seconds')
# ('Number of rows ', 266356)
# ('Loop ', 1, 'took 7.85202598572 seconds')
# ('Number of rows ', 259903)
# ('Loop ', 2, 'took 7.74863100052 seconds')
# ('Number of rows ', 215571)
# ('Loop ', 3, 'took 7.31607484818 seconds')
# ('Number of rows ', 306689)
# ('Loop ', 4, 'took 8.05688691139 seconds')
# ('size of concat_result:', 1267281)
# ('size of yr_agg_result:', 1267281)
# year: 1999
# max_chunk_size: 4400886.0
# ('Number of rows ', 196140)
# ('Loop ', 0, 'took 7.62975811958 seconds')
# ('Number of rows ', 257634)
# ('Loop ', 1, 'took 7.62228512764 seconds')
# ('Number of rows ', 228094)
# ('Loop ', 2, 'took 7.65020608902 seconds')
# ('Number of rows ', 218627)
# ('Loop ', 3, 'took 7.19626808167 seconds')
# ('Number of rows ', 269663)
# ('Loop ', 4, 'took 7.71574401855 seconds')
# ('size of concat_result:', 1170158)
# ('size of yr_agg_result:', 1170158)
# year: 1998
# max_chunk_size: 4181341.0
# ('Number of rows ', 189861)
# ('Loop ', 0, 'took 6.99265909195 seconds')
# ('Number of rows ', 241952)
# ('Loop ', 1, 'took 7.2383518219 seconds')
# ('Number of rows ', 222670)
# ('Loop ', 2, 'took 7.13760995865 seconds')
# ('Number of rows ', 190470)
# ('Loop ', 3, 'took 7.07163691521 seconds')
# ('Number of rows ', 264266)
# ('Loop ', 4, 'took 7.39826607704 seconds')
# ('size of concat_result:', 1109219)
# ('size of yr_agg_result:', 1109219)
# year: 1997
# max_chunk_size: 3860625.0
# ('Number of rows ', 169348)
# ('Loop ', 0, 'took 6.36749601364 seconds')
# ('Number of rows ', 221568)
# ('Loop ', 1, 'took 6.63799309731 seconds')
# ('Number of rows ', 196715)
# ('Loop ', 2, 'took 6.88196396828 seconds')
# ('Number of rows ', 183893)
# ('Loop ', 3, 'took 6.64007496834 seconds')
# ('Number of rows ', 229306)
# ('Loop ', 4, 'took 6.75161099434 seconds')
# ('size of concat_result:', 1000830)
# ('size of yr_agg_result:', 1000830)
# saved at: ./../../../../media/miglesia/Elements/export_france/data/type1/DP1610_MAASTRICHT1_1997_2013/samplings/YMxpb_size2003.csv
# bin no. 2
# year: 2013
# max_chunk_size: 8180411.0
# ('Number of rows ', 275174)
# ('Loop ', 0, 'took 12.4316511154 seconds')
# ('Number of rows ', 375949)
# ('Loop ', 1, 'took 14.1992459297 seconds')
# ('Number of rows ', 315724)
# ('Loop ', 2, 'took 13.2213308811 seconds')
# ('Number of rows ', 271477)
# ('Loop ', 3, 'took 12.524597168 seconds')
# ('Number of rows ', 431653)
# ('Loop ', 4, 'took 13.5490601063 seconds')
# ('size of concat_result:', 1669977)
# ('size of yr_agg_result:', 1669977)
# year: 2012
# max_chunk_size: 7662320.0
# ('Number of rows ', 274601)
# ('Loop ', 0, 'took 12.2138729095 seconds')
# ('Number of rows ', 369071)
# ('Loop ', 1, 'took 12.0638329983 seconds')
# ('Number of rows ', 309960)
# ('Loop ', 2, 'took 12.2787089348 seconds')
# ('Number of rows ', 263312)
# ('Loop ', 3, 'took 11.332983017 seconds')
# ('Number of rows ', 423996)
# ('Loop ', 4, 'took 12.3244009018 seconds')
# ('size of concat_result:', 1640940)
# ('size of yr_agg_result:', 1640940)
# year: 2011
# max_chunk_size: 7195973.0
# ('Number of rows ', 264167)
# ('Loop ', 0, 'took 11.1698520184 seconds')
# ('Number of rows ', 355330)
# ('Loop ', 1, 'took 11.097728014 seconds')
# ('Number of rows ', 306916)
# ('Loop ', 2, 'took 11.7191560268 seconds')
# ('Number of rows ', 272422)
# ('Loop ', 3, 'took 10.9187939167 seconds')
# ('Number of rows ', 398876)
# ('Loop ', 4, 'took 11.6250169277 seconds')
# ('size of concat_result:', 1597711)
# ('size of yr_agg_result:', 1597711)
# year: 2010
# max_chunk_size: 6993649.0
# ('Number of rows ', 258481)
# ('Loop ', 0, 'took 11.2102079391 seconds')
# ('Number of rows ', 375431)
# ('Loop ', 1, 'took 11.9662358761 seconds')
# ('Number of rows ', 290903)
# ('Loop ', 2, 'took 11.9215669632 seconds')
# ('Number of rows ', 281282)
# ('Loop ', 3, 'took 11.1030030251 seconds')
# ('Number of rows ', 397056)
# ('Loop ', 4, 'took 11.9332430363 seconds')
# ('size of concat_result:', 1603153)
# ('size of yr_agg_result:', 1603153)
# year: 2009
# max_chunk_size: 6278669.0
# ('Number of rows ', 261395)
# ('Loop ', 0, 'took 10.0685532093 seconds')
# ('Number of rows ', 348545)
# ('Loop ', 1, 'took 10.2579479218 seconds')
# ('Number of rows ', 292250)
# ('Loop ', 2, 'took 10.5717420578 seconds')
# ('Number of rows ', 282011)
# ('Loop ', 3, 'took 9.99090003967 seconds')
# ('Number of rows ', 372574)
# ('Loop ', 4, 'took 10.7710959911 seconds')
# ('size of concat_result:', 1556775)
# ('size of yr_agg_result:', 1556775)
# year: 2008
# max_chunk_size: 6309116.0
# ('Number of rows ', 285232)
# ('Loop ', 0, 'took 10.5561378002 seconds')
# ('Number of rows ', 316633)
# ('Loop ', 1, 'took 10.2730391026 seconds')
# ('Number of rows ', 349524)
# ('Loop ', 2, 'took 11.0022301674 seconds')
# ('Number of rows ', 265820)
# ('Loop ', 3, 'took 9.96272993088 seconds')
# ('Number of rows ', 401000)
# ('Loop ', 4, 'took 10.964815855 seconds')
# ('size of concat_result:', 1618209)
# ('size of yr_agg_result:', 1618209)
# year: 2007
# max_chunk_size: 6160497.0
# ('Number of rows ', 275037)
# ('Loop ', 0, 'took 10.3407030106 seconds')
# ('Number of rows ', 365500)
# ('Loop ', 1, 'took 11.0996658802 seconds')
# ('Number of rows ', 305728)
# ('Loop ', 2, 'took 9.91721487045 seconds')
# ('Number of rows ', 273330)
# ('Loop ', 3, 'took 9.64201402664 seconds')
# ('Number of rows ', 414859)
# ('Loop ', 4, 'took 10.8362979889 seconds')
# ('size of concat_result:', 1634454)
# ('size of yr_agg_result:', 1634454)
# year: 2006
# max_chunk_size: 5789960.0
# ('Number of rows ', 251066)
# ('Loop ', 0, 'took 9.78657698631 seconds')
# ('Number of rows ', 336653)
# ('Loop ', 1, 'took 10.0127820969 seconds')
# ('Number of rows ', 285973)
# ('Loop ', 2, 'took 10.2363801003 seconds')
# ('Number of rows ', 267971)
# ('Loop ', 3, 'took 9.37937092781 seconds')
# ('Number of rows ', 383036)
# ('Loop ', 4, 'took 10.0318188667 seconds')
# ('size of concat_result:', 1524699)
# ('size of yr_agg_result:', 1524699)
# year: 2005
# max_chunk_size: 5559688.0
# ('Number of rows ', 240111)
# ('Loop ', 0, 'took 9.08154296875 seconds')
# ('Number of rows ', 332796)
# ('Loop ', 1, 'took 9.48034596443 seconds')
# ('Number of rows ', 280186)
# ('Loop ', 2, 'took 9.38573598862 seconds')
# ('Number of rows ', 256190)
# ('Loop ', 3, 'took 9.21858906746 seconds')
# ('Number of rows ', 374262)
# ('Loop ', 4, 'took 9.43493294716 seconds')
# ('size of concat_result:', 1483545)
# ('size of yr_agg_result:', 1483545)
# year: 2004
# max_chunk_size: 5218704.0
# ('Number of rows ', 226325)
# ('Loop ', 0, 'took 8.67711997032 seconds')
# ('Number of rows ', 313017)
# ('Loop ', 1, 'took 8.77162694931 seconds')
# ('Number of rows ', 264707)
# ('Loop ', 2, 'took 9.18614196777 seconds')
# ('Number of rows ', 249731)
# ('Loop ', 3, 'took 8.87371110916 seconds')
# ('Number of rows ', 351848)
# ('Loop ', 4, 'took 9.00141310692 seconds')
# ('size of concat_result:', 1405628)
# ('size of yr_agg_result:', 1405628)
# year: 2003
# max_chunk_size: 4899719.0
# ('Number of rows ', 219949)
# ('Loop ', 0, 'took 8.72051000595 seconds')
# ('Number of rows ', 279004)
# ('Loop ', 1, 'took 8.3147380352 seconds')
# ('Number of rows ', 271177)
# ('Loop ', 2, 'took 8.45225191116 seconds')
# ('Number of rows ', 210481)
# ('Loop ', 3, 'took 8.09044194221 seconds')
# ('Number of rows ', 333966)
# ('Loop ', 4, 'took 8.57749414444 seconds')
# ('size of concat_result:', 1314577)
# ('size of yr_agg_result:', 1314577)
# year: 2002
# max_chunk_size: 4739381.0
# ('Number of rows ', 212056)
# ('Loop ', 0, 'took 8.16496610641 seconds')
# ('Number of rows ', 274135)
# ('Loop ', 1, 'took 8.37032389641 seconds')
# ('Number of rows ', 257576)
# ('Loop ', 2, 'took 8.40464019775 seconds')
# ('Number of rows ', 202488)
# ('Loop ', 3, 'took 8.03708410263 seconds')
# ('Number of rows ', 319564)
# ('Loop ', 4, 'took 8.82005906105 seconds')
# ('size of concat_result:', 1265819)
# ('size of yr_agg_result:', 1265819)
# year: 2001
# max_chunk_size: 4634439.0
# ('Number of rows ', 216986)
# ('Loop ', 0, 'took 8.27549791336 seconds')
# ('Number of rows ', 255996)
# ('Loop ', 1, 'took 8.15287184715 seconds')
# ('Number of rows ', 282020)
# ('Loop ', 2, 'took 8.24289894104 seconds')
# ('Number of rows ', 200716)
# ('Loop ', 3, 'took 7.61635494232 seconds')
# ('Number of rows ', 316904)
# ('Loop ', 4, 'took 7.9969420433 seconds')
# ('size of concat_result:', 1272622)
# ('size of yr_agg_result:', 1272622)
# year: 2000
# max_chunk_size: 4608999.0
# ('Number of rows ', 217869)
# ('Loop ', 0, 'took 8.18734383583 seconds')
# ('Number of rows ', 272754)
# ('Loop ', 1, 'took 7.98510313034 seconds')
# ('Number of rows ', 265880)
# ('Loop ', 2, 'took 7.78035187721 seconds')
# ('Number of rows ', 209005)
# ('Loop ', 3, 'took 7.56165885925 seconds')
# ('Number of rows ', 323393)
# ('Loop ', 4, 'took 8.06461405754 seconds')
# ('size of concat_result:', 1288901)
# ('size of yr_agg_result:', 1288901)
# year: 1999
# max_chunk_size: 4400886.0
# ('Number of rows ', 213552)
# ('Loop ', 0, 'took 7.45406198502 seconds')
# ('Number of rows ', 293026)
# ('Loop ', 1, 'took 7.4977118969 seconds')
# ('Number of rows ', 253473)
# ('Loop ', 2, 'took 7.6757080555 seconds')
# ('Number of rows ', 222713)
# ('Loop ', 3, 'took 7.72644090652 seconds')
# ('Number of rows ', 306606)
# ('Loop ', 4, 'took 7.80847191811 seconds')
# ('size of concat_result:', 1289370)
# ('size of yr_agg_result:', 1289370)
# year: 1998
# max_chunk_size: 4181341.0
# ('Number of rows ', 211020)
# ('Loop ', 0, 'took 7.19528388977 seconds')
# ('Number of rows ', 276496)
# ('Loop ', 1, 'took 7.15524101257 seconds')
# ('Number of rows ', 247403)
# ('Loop ', 2, 'took 7.16370010376 seconds')
# ('Number of rows ', 214562)
# ('Loop ', 3, 'took 6.92112112045 seconds')
# ('Number of rows ', 310069)
# ('Loop ', 4, 'took 7.42505216599 seconds')
# ('size of concat_result:', 1259550)
# ('size of yr_agg_result:', 1259550)
# year: 1997
# max_chunk_size: 3860625.0
# ('Number of rows ', 189361)
# ('Loop ', 0, 'took 6.4626019001 seconds')
# ('Number of rows ', 253577)
# ('Loop ', 1, 'took 7.28961610794 seconds')
# ('Number of rows ', 221694)
# ('Loop ', 2, 'took 6.99353981018 seconds')
# ('Number of rows ', 213351)
# ('Loop ', 3, 'took 6.47986698151 seconds')
# ('Number of rows ', 275486)
# ('Loop ', 4, 'took 6.81919813156 seconds')
# ('size of concat_result:', 1153469)
# ('size of yr_agg_result:', 1153469)
# saved at: ./../../../../media/miglesia/Elements/export_france/data/type1/DP1610_MAASTRICHT1_1997_2013/samplings/YMxpb_size2002.csv
# bin no. 1
# year: 2013
# max_chunk_size: 8180411.0
# ('Number of rows ', 210008)
# ('Loop ', 0, 'took 12.3223218918 seconds')
# ('Number of rows ', 299799)
# ('Loop ', 1, 'took 12.7915878296 seconds')
# ('Number of rows ', 248966)
# ('Loop ', 2, 'took 13.6459929943 seconds')
# ('Number of rows ', 220146)
# ('Loop ', 3, 'took 12.6717000008 seconds')
# ('Number of rows ', 353073)
# ('Loop ', 4, 'took 13.6362068653 seconds')
# ('size of concat_result:', 1331992)
# ('size of yr_agg_result:', 1331992)
# year: 2012
# max_chunk_size: 7662320.0
# ('Number of rows ', 194624)
# ('Loop ', 0, 'took 12.2407329082 seconds')
# ('Number of rows ', 276254)
# ('Loop ', 1, 'took 12.2261462212 seconds')
# ('Number of rows ', 228064)
# ('Loop ', 2, 'took 11.9201741219 seconds')
# ('Number of rows ', 196807)
# ('Loop ', 3, 'took 11.2188818455 seconds')
# ('Number of rows ', 320850)
# ('Loop ', 4, 'took 12.2224521637 seconds')
# ('size of concat_result:', 1216599)
# ('size of yr_agg_result:', 1216599)
# year: 2011
# max_chunk_size: 7195973.0
# ('Number of rows ', 188210)
# ('Loop ', 0, 'took 11.0274319649 seconds')
# ('Number of rows ', 263001)
# ('Loop ', 1, 'took 11.4971220493 seconds')
# ('Number of rows ', 227595)
# ('Loop ', 2, 'took 11.6340911388 seconds')
# ('Number of rows ', 195119)
# ('Loop ', 3, 'took 11.05519104 seconds')
# ('Number of rows ', 293092)
# ('Loop ', 4, 'took 11.573182106 seconds')
# ('size of concat_result:', 1167017)
# ('size of yr_agg_result:', 1167017)
# year: 2010
# max_chunk_size: 6993649.0
# ('Number of rows ', 211285)
# ('Loop ', 0, 'took 11.2442529202 seconds')
# ('Number of rows ', 330490)
# ('Loop ', 1, 'took 11.6843509674 seconds')
# ('Number of rows ', 250293)
# ('Loop ', 2, 'took 11.8860309124 seconds')
# ('Number of rows ', 234166)
# ('Loop ', 3, 'took 11.1524438858 seconds')
# ('Number of rows ', 344552)
# ('Loop ', 4, 'took 11.8253781796 seconds')
# ('size of concat_result:', 1370786)
# ('size of yr_agg_result:', 1370786)
# year: 2009
# max_chunk_size: 6278669.0
# ('Number of rows ', 210017)
# ('Loop ', 0, 'took 9.91532301903 seconds')
# ('Number of rows ', 295821)
# ('Loop ', 1, 'took 10.2788188457 seconds')
# ('Number of rows ', 248529)
# ('Loop ', 2, 'took 10.5106999874 seconds')
# ('Number of rows ', 231906)
# ('Loop ', 3, 'took 9.98880696297 seconds')
# ('Number of rows ', 332954)
# ('Loop ', 4, 'took 10.7189130783 seconds')
# ('size of concat_result:', 1319227)
# ('size of yr_agg_result:', 1319227)
# year: 2008
# max_chunk_size: 6309116.0
# ('Number of rows ', 234779)
# ('Loop ', 0, 'took 10.4485518932 seconds')
# ('Number of rows ', 265838)
# ('Loop ', 1, 'took 10.305836916 seconds')
# ('Number of rows ', 301455)
# ('Loop ', 2, 'took 10.8091890812 seconds')
# ('Number of rows ', 216116)
# ('Loop ', 3, 'took 10.075150013 seconds')
# ('Number of rows ', 336145)
# ('Loop ', 4, 'took 10.9854369164 seconds')
# ('size of concat_result:', 1354333)
# ('size of yr_agg_result:', 1354333)
# year: 2007
# max_chunk_size: 6160497.0
# ('Number of rows ', 221116)
# ('Loop ', 0, 'took 10.4202079773 seconds')
# ('Number of rows ', 315725)
# ('Loop ', 1, 'took 10.6728129387 seconds')
# ('Number of rows ', 264598)
# ('Loop ', 2, 'took 11.3918001652 seconds')
# ('Number of rows ', 223166)
# ('Loop ', 3, 'took 9.89336585999 seconds')
# ('Number of rows ', 347550)
# ('Loop ', 4, 'took 10.8303041458 seconds')
# ('size of concat_result:', 1372155)
# ('size of yr_agg_result:', 1372155)
# year: 2006
# max_chunk_size: 5789960.0
# ('Number of rows ', 206811)
# ('Loop ', 0, 'took 10.0318100452 seconds')
# ('Number of rows ', 287168)
# ('Loop ', 1, 'took 9.64735603333 seconds')
# ('Number of rows ', 248649)
# ('Loop ', 2, 'took 9.89757585526 seconds')
# ('Number of rows ', 220246)
# ('Loop ', 3, 'took 9.47171497345 seconds')
# ('Number of rows ', 330377)
# ('Loop ', 4, 'took 9.84766602516 seconds')
# ('size of concat_result:', 1293251)
# ('size of yr_agg_result:', 1293251)
# year: 2005
# max_chunk_size: 5559688.0
# ('Number of rows ', 193950)
# ('Loop ', 0, 'took 9.05073189735 seconds')
# ('Number of rows ', 278199)
# ('Loop ', 1, 'took 9.36858201027 seconds')
# ('Number of rows ', 236850)
# ('Loop ', 2, 'took 9.20195007324 seconds')
# ('Number of rows ', 209467)
# ('Loop ', 3, 'took 8.94646406174 seconds')
# ('Number of rows ', 315020)
# ('Loop ', 4, 'took 9.34483194351 seconds')
# ('size of concat_result:', 1233486)
# ('size of yr_agg_result:', 1233486)
# year: 2004
# max_chunk_size: 5218704.0
# ('Number of rows ', 185035)
# ('Loop ', 0, 'took 8.51247191429 seconds')
# ('Number of rows ', 266386)
# ('Loop ', 1, 'took 8.88177013397 seconds')
# ('Number of rows ', 221735)
# ('Loop ', 2, 'took 9.07866001129 seconds')
# ('Number of rows ', 198156)
# ('Loop ', 3, 'took 8.59712505341 seconds')
# ('Number of rows ', 297171)
# ('Loop ', 4, 'took 8.89384889603 seconds')
# ('size of concat_result:', 1168483)
# ('size of yr_agg_result:', 1168483)
# year: 2003
# max_chunk_size: 4899719.0
# ('Number of rows ', 179985)
# ('Loop ', 0, 'took 8.27650690079 seconds')
# ('Number of rows ', 231001)
# ('Loop ', 1, 'took 8.21824097633 seconds')
# ('Number of rows ', 221320)
# ('Loop ', 2, 'took 8.4421620369 seconds')
# ('Number of rows ', 172411)
# ('Loop ', 3, 'took 8.0600168705 seconds')
# ('Number of rows ', 283763)
# ('Loop ', 4, 'took 8.54141902924 seconds')
# ('size of concat_result:', 1088480)
# ('size of yr_agg_result:', 1088480)
# year: 2002
# max_chunk_size: 4739381.0
# ('Number of rows ', 174481)
# ('Loop ', 0, 'took 8.18842387199 seconds')
# ('Number of rows ', 235163)
# ('Loop ', 1, 'took 8.524050951 seconds')
# ('Number of rows ', 219996)
# ('Loop ', 2, 'took 8.56770992279 seconds')
# ('Number of rows ', 170618)
# ('Loop ', 3, 'took 7.89009904861 seconds')
# ('Number of rows ', 280931)
# ('Loop ', 4, 'took 8.5842628479 seconds')
# ('size of concat_result:', 1081189)
# ('size of yr_agg_result:', 1081189)
# year: 2001
# max_chunk_size: 4634439.0
# ('Number of rows ', 176350)
# ('Loop ', 0, 'took 8.22647190094 seconds')
# ('Number of rows ', 219766)
# ('Loop ', 1, 'took 8.00388002396 seconds')
# ('Number of rows ', 240547)
# ('Loop ', 2, 'took 8.19156098366 seconds')
# ('Number of rows ', 167897)
# ('Loop ', 3, 'took 7.65350604057 seconds')
# ('Number of rows ', 277978)
# ('Loop ', 4, 'took 8.06470298767 seconds')
# ('size of concat_result:', 1082538)
# ('size of yr_agg_result:', 1082538)
# year: 2000
# max_chunk_size: 4608999.0
# ('Number of rows ', 177075)
# ('Loop ', 0, 'took 8.02353000641 seconds')
# ('Number of rows ', 232443)
# ('Loop ', 1, 'took 7.90817499161 seconds')
# ('Number of rows ', 231631)
# ('Loop ', 2, 'took 7.82211685181 seconds')
# ('Number of rows ', 176832)
# ('Loop ', 3, 'took 7.45003199577 seconds')
# ('Number of rows ', 283967)
# ('Loop ', 4, 'took 8.16025114059 seconds')
# ('size of concat_result:', 1101948)
# ('size of yr_agg_result:', 1101948)
# year: 1999
# max_chunk_size: 4400886.0
# ('Number of rows ', 165870)
# ('Loop ', 0, 'took 7.2818300724 seconds')
# ('Number of rows ', 241551)
# ('Loop ', 1, 'took 7.30010294914 seconds')
# ('Number of rows ', 206143)
# ('Loop ', 2, 'took 7.52701091766 seconds')
# ('Number of rows ', 178047)
# ('Loop ', 3, 'took 7.18953204155 seconds')
# ('Number of rows ', 271876)
# ('Loop ', 4, 'took 7.71910095215 seconds')
# ('size of concat_result:', 1063487)
# ('size of yr_agg_result:', 1063487)
# year: 1998
# max_chunk_size: 4181341.0
# ('Number of rows ', 166376)
# ('Loop ', 0, 'took 7.36059308052 seconds')
# ('Number of rows ', 227372)
# ('Loop ', 1, 'took 7.24661302567 seconds')
# ('Number of rows ', 200894)
# ('Loop ', 2, 'took 7.41306710243 seconds')
# ('Number of rows ', 166124)
# ('Loop ', 3, 'took 7.0351960659 seconds')
# ('Number of rows ', 257551)
# ('Loop ', 4, 'took 7.45724201202 seconds')
# ('size of concat_result:', 1018317)
# ('size of yr_agg_result:', 1018317)
# year: 1997
# max_chunk_size: 3860625.0
# ('Number of rows ', 153412)
# ('Loop ', 0, 'took 6.43668103218 seconds')
# ('Number of rows ', 216633)
# ('Loop ', 1, 'took 7.21626782417 seconds')
# ('Number of rows ', 175391)
# ('Loop ', 2, 'took 6.84858298302 seconds')
# ('Number of rows ', 161146)
# ('Loop ', 3, 'took 6.56433796883 seconds')
# ('Number of rows ', 232563)
# ('Loop ', 4, 'took 6.78733205795 seconds')
# ('size of concat_result:', 939145)
# ('size of yr_agg_result:', 939145)
# saved at: ./../../../../media/miglesia/Elements/export_france/data/type1/DP1610_MAASTRICHT1_1997_2013/samplings/YMxpb_size2001.csv
# bin no. 0
# year: 2013
# max_chunk_size: 8180411.0
# ('Number of rows ', 46866)
# ('Loop ', 0, 'took 12.4773077965 seconds')
# ('Number of rows ', 70479)
# ('Loop ', 1, 'took 12.7108571529 seconds')
# ('Number of rows ', 61784)
# ('Loop ', 2, 'took 13.459654808 seconds')
# ('Number of rows ', 53088)
# ('Loop ', 3, 'took 12.7192320824 seconds')
# ('Number of rows ', 96495)
# ('Loop ', 4, 'took 13.3717770576 seconds')
# ('size of concat_result:', 328712)
# ('size of yr_agg_result:', 328712)
# year: 2012
# max_chunk_size: 7662320.0
# ('Number of rows ', 39468)
# ('Loop ', 0, 'took 12.2310299873 seconds')
# ('Number of rows ', 56835)
# ('Loop ', 1, 'took 12.0311210155 seconds')
# ('Number of rows ', 49749)
# ('Loop ', 2, 'took 11.7820680141 seconds')
# ('Number of rows ', 40407)
# ('Loop ', 3, 'took 11.1872339249 seconds')
# ('Number of rows ', 71733)
# ('Loop ', 4, 'took 11.9518699646 seconds')
# ('size of concat_result:', 258192)
# ('size of yr_agg_result:', 258192)
# year: 2011
# max_chunk_size: 7195973.0
# ('Number of rows ', 44048)
# ('Loop ', 0, 'took 11.0103309155 seconds')
# ('Number of rows ', 54413)
# ('Loop ', 1, 'took 10.9447920322 seconds')
# ('Number of rows ', 48596)
# ('Loop ', 2, 'took 11.5905990601 seconds')
# ('Number of rows ', 37986)
# ('Loop ', 3, 'took 11.0336539745 seconds')
# ('Number of rows ', 60799)
# ('Loop ', 4, 'took 11.3543701172 seconds')
# ('size of concat_result:', 245842)
# ('size of yr_agg_result:', 245842)
# year: 2010
# max_chunk_size: 6993649.0
# ('Number of rows ', 120242)
# ('Loop ', 0, 'took 11.2128720284 seconds')
# ('Number of rows ', 188074)
# ('Loop ', 1, 'took 11.5563399792 seconds')
# ('Number of rows ', 149729)
# ('Loop ', 2, 'took 11.8762290478 seconds')
# ('Number of rows ', 132983)
# ('Loop ', 3, 'took 11.0515599251 seconds')
# ('Number of rows ', 205637)
# ('Loop ', 4, 'took 12.8889000416 seconds')
# ('size of concat_result:', 796665)
# ('size of yr_agg_result:', 796665)
# year: 2009
# max_chunk_size: 6278669.0
# ('Number of rows ', 121454)
# ('Loop ', 0, 'took 9.83725214005 seconds')
# ('Number of rows ', 170843)
# ('Loop ', 1, 'took 10.1771719456 seconds')
# ('Number of rows ', 151703)
# ('Loop ', 2, 'took 10.3544809818 seconds')
# ('Number of rows ', 133287)
# ('Loop ', 3, 'took 9.74606084824 seconds')
# ('Number of rows ', 198652)
# ('Loop ', 4, 'took 10.4937798977 seconds')
# ('size of concat_result:', 775939)
# ('size of yr_agg_result:', 775939)
# year: 2008
# max_chunk_size: 6309116.0
# ('Number of rows ', 134230)
# ('Loop ', 0, 'took 10.2068839073 seconds')
# ('Number of rows ', 155050)
# ('Loop ', 1, 'took 10.0187540054 seconds')
# ('Number of rows ', 179958)
# ('Loop ', 2, 'took 10.5641689301 seconds')
# ('Number of rows ', 123655)
# ('Loop ', 3, 'took 9.72345590591 seconds')
# ('Number of rows ', 204917)
# ('Loop ', 4, 'took 10.8768930435 seconds')
# ('size of concat_result:', 797810)
# ('size of yr_agg_result:', 797810)
# year: 2007
# max_chunk_size: 6160497.0
# ('Number of rows ', 127377)
# ('Loop ', 0, 'took 10.3167090416 seconds')
# ('Number of rows ', 180257)
# ('Loop ', 1, 'took 10.1233460903 seconds')
# ('Number of rows ', 156847)
# ('Loop ', 2, 'took 9.73970603943 seconds')
# ('Number of rows ', 129440)
# ('Loop ', 3, 'took 9.55898284912 seconds')
# ('Number of rows ', 211867)
# ('Loop ', 4, 'took 10.5125598907 seconds')
# ('size of concat_result:', 805788)
# ('size of yr_agg_result:', 805788)
# year: 2006
# max_chunk_size: 5789960.0
# ('Number of rows ', 125330)
# ('Loop ', 0, 'took 9.58261799812 seconds')
# ('Number of rows ', 175160)
# ('Loop ', 1, 'took 9.43705391884 seconds')
# ('Number of rows ', 155224)
# ('Loop ', 2, 'took 9.71763205528 seconds')
# ('Number of rows ', 128853)
# ('Loop ', 3, 'took 9.32236504555 seconds')
# ('Number of rows ', 204130)
# ('Loop ', 4, 'took 9.72869300842 seconds')
# ('size of concat_result:', 788697)
# ('size of yr_agg_result:', 788697)
# year: 2005
# max_chunk_size: 5559688.0
# ('Number of rows ', 122833)
# ('Loop ', 0, 'took 8.95552897453 seconds')
# ('Number of rows ', 179340)
# ('Loop ', 1, 'took 9.22417998314 seconds')
# ('Number of rows ', 158610)
# ('Loop ', 2, 'took 9.08595108986 seconds')
# ('Number of rows ', 134060)
# ('Loop ', 3, 'took 8.75310587883 seconds')
# ('Number of rows ', 211920)
# ('Loop ', 4, 'took 9.13330292702 seconds')
# ('size of concat_result:', 806763)
# ('size of yr_agg_result:', 806763)
# year: 2004
# max_chunk_size: 5218704.0
# ('Number of rows ', 120862)
# ('Loop ', 0, 'took 8.24075317383 seconds')
# ('Number of rows ', 177724)
# ('Loop ', 1, 'took 8.63348984718 seconds')
# ('Number of rows ', 149055)
# ('Loop ', 2, 'took 8.97296905518 seconds')
# ('Number of rows ', 129520)
# ('Loop ', 3, 'took 9.09092497826 seconds')
# ('Number of rows ', 201245)
# ('Loop ', 4, 'took 8.75457692146 seconds')
# ('size of concat_result:', 778406)
# ('size of yr_agg_result:', 778406)
# year: 2003
# max_chunk_size: 4899719.0
# ('Number of rows ', 122146)
# ('Loop ', 0, 'took 8.20651984215 seconds')
# ('Number of rows ', 158118)
# ('Loop ', 1, 'took 8.12222218513 seconds')
# ('Number of rows ', 155740)
# ('Loop ', 2, 'took 8.46171808243 seconds')
# ('Number of rows ', 112397)
# ('Loop ', 3, 'took 7.99388599396 seconds')
# ('Number of rows ', 195666)
# ('Loop ', 4, 'took 8.44665503502 seconds')
# ('size of concat_result:', 744067)
# ('size of yr_agg_result:', 744067)
# year: 2002
# max_chunk_size: 4739381.0
# ('Number of rows ', 119409)
# ('Loop ', 0, 'took 8.05939698219 seconds')
# ('Number of rows ', 160900)
# ('Loop ', 1, 'took 8.40305805206 seconds')
# ('Number of rows ', 157461)
# ('Loop ', 2, 'took 8.29251098633 seconds')
# ('Number of rows ', 115605)
# ('Loop ', 3, 'took 7.65199899673 seconds')
# ('Number of rows ', 197634)
# ('Loop ', 4, 'took 8.37310910225 seconds')
# ('size of concat_result:', 751009)
# ('size of yr_agg_result:', 751009)
# year: 2001
# max_chunk_size: 4634439.0
# ('Number of rows ', 126480)
# ('Loop ', 0, 'took 8.09114289284 seconds')
# ('Number of rows ', 151122)
# ('Loop ', 1, 'took 8.17116904259 seconds')
# ('Number of rows ', 173700)
# ('Loop ', 2, 'took 8.15571689606 seconds')
# ('Number of rows ', 114294)
# ('Loop ', 3, 'took 7.49006390572 seconds')
# ('Number of rows ', 197472)
# ('Loop ', 4, 'took 8.01487088203 seconds')
# ('size of concat_result:', 763068)
# ('size of yr_agg_result:', 763068)
# year: 2000
# max_chunk_size: 4608999.0
# ('Number of rows ', 133834)
# ('Loop ', 0, 'took 7.75966596603 seconds')
# ('Number of rows ', 173015)
# ('Loop ', 1, 'took 7.74942803383 seconds')
# ('Number of rows ', 184540)
# ('Loop ', 2, 'took 7.6309800148 seconds')
# ('Number of rows ', 128214)
# ('Loop ', 3, 'took 7.31549882889 seconds')
# ('Number of rows ', 226888)
# ('Loop ', 4, 'took 7.77970218658 seconds')
# ('size of concat_result:', 846491)
# ('size of yr_agg_result:', 846491)
# year: 1999
# max_chunk_size: 4400886.0
# ('Number of rows ', 128551)
# ('Loop ', 0, 'took 7.15037608147 seconds')
# ('Number of rows ', 191231)
# ('Loop ', 1, 'took 7.28367495537 seconds')
# ('Number of rows ', 164708)
# ('Loop ', 2, 'took 7.37910604477 seconds')
# ('Number of rows ', 135204)
# ('Loop ', 3, 'took 6.99371981621 seconds')
# ('Number of rows ', 220193)
# ('Loop ', 4, 'took 7.51793289185 seconds')
# ('size of concat_result:', 839887)
# ('size of yr_agg_result:', 839884)
# year: 1998
# max_chunk_size: 4181341.0
# ('Number of rows ', 131538)
# ('Loop ', 0, 'took 7.1519780159 seconds')
# ('Number of rows ', 181386)
# ('Loop ', 1, 'took 7.37988495827 seconds')
# ('Number of rows ', 166949)
# ('Loop ', 2, 'took 7.14707517624 seconds')
# ('Number of rows ', 131218)
# ('Loop ', 3, 'took 6.8687620163 seconds')
# ('Number of rows ', 216668)
# ('Loop ', 4, 'took 7.24938702583 seconds')
# ('size of concat_result:', 827759)
# ('size of yr_agg_result:', 827759)
# year: 1997
# max_chunk_size: 3860625.0
# ('Number of rows ', 143504)
# ('Loop ', 0, 'took 6.55765485764 seconds')
# ('Number of rows ', 204072)
# ('Loop ', 1, 'took 7.13397908211 seconds')
# ('Number of rows ', 162008)
# ('Loop ', 2, 'took 6.83978891373 seconds')
# ('Number of rows ', 147035)
# ('Loop ', 3, 'took 6.47169709206 seconds')
# ('Number of rows ', 211032)
# ('Loop ', 4, 'took 6.84014511108 seconds')
# ('size of concat_result:', 867651)
# ('size of yr_agg_result:', 867651)
# saved at: ./../../../../media/miglesia/Elements/export_france/data/type1/DP1610_MAASTRICHT1_1997_2013/samplings/YMxpb_size2000.csv
# /home/miglesia/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2825: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):

# %%
# # Imports and exports by firm/year

# IDs = firm_stats['ID']
# Mns = [1, 2, 3]

# def sample_data(columns, index = ['ID', 'IMPORT','YEAR'], chunk_agg = True, chunk_agg_func = {}, 
#             yr_agg_func = {}, name = 'test_sampling', n_chunks = 30.,
#                 firm_filtering = True, firm_filtering_cols = ['ID'], firm_filtering_arrays = [IDs],
#                 time_filtering = False, time_filtering_arrays = [Mns],
#                 verbose = False, yr_chunks_agg = True, save_yr_agg_result = False,
#                data_path = path1, save_path = path1+'/samplings/', select_IMPORTS = None):

#     names = tuple(index)
#     sampling_name = name

#     l = []

#     for y in years:
#         print 'year: '+str(y)
#         #Rows for each chunk
#         size = np.ceil(nrows1[y]/n_chunks)
#         print 'max_chunk_size: '+str(size)

#         reader = pd.read_csv(data_path+'/DP1610_MAASTRICHT1_'+str(y)+'.txt', chunksize = size, 
#                              usecols = map(colname_no.get, columns)
#                              , delimiter = ';', header = None) #'CN ID 8', 'PYOD'

#         yr_result_list = []

#         for i in range(int(n_chunks)):
#             start_time = time.time()
#             chunk = next(reader).rename(colno_name, axis = 1)
#             chunk['IMPORT'] = chunk['FLUX'] % 2 # so that '1' indicates imports
# #             print chunk.head()

#             if firm_filtering == True:
#                 for i in range(len(firm_filtering_cols)):
#                     chunk = chunk.loc[chunk[firm_filtering_cols[i]].isin(firm_filtering_arrays[i])]
#                     print 'filtered_chunk_size: '+str(len(chunk))
# #             print chunk.head()
                    
#             if time_filtering == True:
#                 time_filtering_cols = ['MONTH']
#                 for i in range(len(time_filtering_cols)):
#                     chunk = chunk.loc[chunk[time_filtering_cols[i]].isin(time_filtering_arrays[i])]
#                     print 'filtered_chunk_size: '+str(len(chunk))

#             if select_IMPORTS != None: chunk = chunk.loc[chunk.IMPORT == select_IMPORTS]

#             if chunk_agg: 
#                 result_chunk = aggregation(chunk, index, chunk_agg_func)
#             else: 
#                 result_chunk = chunk
                
# #             print result_chunk.head()

#             yr_result_list += [result_chunk]
#             if verbose: print("Number of rows ",result_chunk.shape[0])
#             if verbose: print("Loop ",i,"took %s seconds" % (time.time() - start_time))
#             del(result_chunk) 


#         concat_result = pd.concat(yr_result_list)
# #         print concat_result.head()
        
#         # Unique users vs Number of rows after the first computation    
#         if verbose: print("size of concat_result:", len(concat_result))
# #         if verbose: print("unique firms in concat_result:", len(concat_result.index.unique()))

#         result = concat_result
#         result.columns = ['_'.join(col).strip() for col in result.columns.values]

#         if yr_chunks_agg:
# #             yr_agg_result = result.groupby(index).agg(yr_agg_func)
#             yr_agg_result = aggregation(result, index, yr_agg_func)
#             yr_agg_result.index = pd.MultiIndex.from_tuples(list(yr_agg_result.index), names=names)
#             yr_agg_result.columns = yr_agg_result.columns.droplevel(1)

#         else:
#             yr_agg_result = result

#         if verbose: print("size of yr_agg_result:", len(yr_agg_result))

#         l += [yr_agg_result]

#         if save_yr_agg_result:
#             yr_agg_result.to_csv(save_path+'/'+sampling_name+'_'+str(y)+'.csv')
    
#     filename = save_path+'/'+sampling_name+'.csv'
#     pd.concat(l).to_csv(filename, index = True)
#     print 'saved at: '+str(filename)

# %%
# sizes_index = pd.read_csv('./../export_france/data/formatted/sizes_index.csv')

# n = 10

# sizes_index['log_exp_mma'] = np.log10(sizes_index.exp_mma).round(3)
# cuts = pd.cut(sizes_index.groupby(sizes_index['log_exp_mma']).sum().cumsum()['exp_mma'],n, labels=range(n))
# exp_index = sizes_index.merge(cuts.reset_index().rename({'exp_mma': 'exp_mma_cat'}, axis = 1), on = 'log_exp_mma').dropna(subset = ['exp_mma'])

# %%
# # Oct 4
# sizes_index = pd.read_csv('./../export_france/data/formatted/sizes_index.csv', index_col=0)
# n = 20
# exp_index = sizes_index.dropna(subset = ['exp_mma'])
# exp_index['exp_qcut_'+str(n)+'_label'] = pd.qcut(exp_index['exp_mma'], n, labels=range(n))
# exp_index['exp_qcut_'+str(n)] = pd.qcut(exp_index['exp_mma'], n)

# # imp_index = sizes_index.dropna(subset = ['imp_mma'])
# # imp_index['imp_cut_'+str(n)+'_label'] = pd.cut(imp_index['imp_mma'], n, labels=range(n))
# # imp_index['imp_cut_'+str(n)] = pd.cut(imp_index['imp_mma'], n)

# %%
# Mns = range(1,13)
# time_filtering_arrays = [Mns]

# # use all firms
# sample_n_firms = 'max'

# years = list(reversed(range(1997, 2014)))

# for bin_label in list(reversed(range(n))):
#     print 'bin label: '+str(bin_label)
#     IDs = exp_index.loc[exp_index.exp_mma_cat == bin_label].index
#     print IDs
# #     IDs = imp_index.loc[imp_index.imp_cut_20_label == bin_label].index
#     columns = ['YEAR', 'MONTH', 'FLUX', 'ID', 'CN ID 8', 'VAT','VART']
#     sample_data(columns, index = ['YEAR', 'MONTH', 'IMPORT', 'ID', 'CN ID 8', 'VAT'], chunk_agg_func = {'VART':['sum']}, 
#                 firm_filtering = True, firm_filtering_cols = ['ID'], firm_filtering_arrays = [IDs],
#                 yr_agg_func = {'VART_sum':['sum']}, n_chunks = 10., 
#                 name = 'firm_sample_YMxpb_n'+str(n).zfill(2)+str(bin_label).zfill(2),
#                 verbose = False, yr_chunks_agg = True, select_IMPORTS = 0, save_yr_agg_result = True)
