# %%
import pandas as pd
data_path = './../../data/processed/'

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv(data_path + 'export_bundles_qr.csv')
df = df.loc[df.YEAR < 2001]

# %% [markdown]
# ### Growth rates

# %%
table_levels = df.groupby(['ID','YEAR'])[['VART']].sum().unstack()

# %%
grs = np.log10(table_levels).diff(1, axis = 1).stack().rename(columns = {'VART': 'yr_log_diff'}).reset_index()

# grs_gauss = grs.loc[(grs.yr_log_diff > grs.yr_log_diff.quantile(.33)) & (grs.yr_log_diff < grs.yr_log_diff.quantile(.67)) ]
# plt.hist(grs_gauss.yr_log_diff.values, 50)
# plt.yscale('log')
# plt.show()

# grs['Gaussian'] = (grs.yr_log_diff > grs.yr_log_diff.quantile(.33)) & (grs.yr_log_diff < grs.yr_log_diff.quantile(.67))
grs['Gaussian'] = (grs.yr_log_diff > -0.06) & (grs.yr_log_diff < 0.09)
# grs.loc[grs['Gaussian']]

grs['Category'] = pd.qcut(grs.yr_log_diff, 3, labels = ['Shrinkage', 'Fluctuation', 'Expansion'])

# %% [markdown]
# ### Margins

# %%
F = df.groupby(['ID', 'YEAR', 'QUARTER'])['VART'].sum().unstack([-2, -1]).sort_index(axis = 1)
FP = df.groupby(['ID','CN ID 4', 'YEAR', 'QUARTER'])['VART'].sum().unstack([-2, -1]).sort_index(axis = 1)
FC = df.groupby(['ID','PYOD', 'YEAR', 'QUARTER'])['VART'].sum().unstack([-2, -1]).sort_index(axis = 1)
FPC = df.groupby(['ID','CN ID 4', 'PYOD', 'YEAR', 'QUARTER'])['VART'].sum().unstack([-2, -1]).sort_index(axis = 1)
FB = df.groupby(['ID','VAT', 'YEAR', 'QUARTER'])['VART'].sum().unstack([-2, -1]).sort_index(axis = 1)

# %%
# # b = df_.cumsum(1)
# # c1 = b.sub(b.mask(df_).ffill(1).fillna(0)).astype(int)
# df_ = FP > 0
# b = df_.cumsum(1)
# #how long since current active period started
# c1 = b.sub(b.mask(df_).ffill(1).fillna(0)).astype(int)
# b = (~df_).cumsum(1)
# #how long since current INactive period started
# c0 = -b.sub(b.mask(~df_).ffill(1).fillna(0)).astype(int)

# %%
import numpy as np

def get_diff(table):
    # Interpolation, but the inerpolate method gets stuck
    ffill = (table > 0).astype(int).replace(0, np.nan).ffill(1, limit = 3)#.astype(int)
    bfill = (1 - ffill.fillna(0)).replace(0, np.nan).bfill(1, limit = 3)

    # ffilled gaps times zero when closure is definitive
    ffill = ffill.fillna(0).astype(int)
    bfill = 1 - bfill.fillna(0).astype(int)

    diff = bfill.diff(4, axis = 1) #table

    return diff

# %%
diff = get_diff(FPC)
diff_FPC = diff.stack([-2, -1]).reset_index().rename(columns = {0: 'margin_FPC'}) #long

diff = get_diff(FB)
diff_FB = diff.stack([-2, -1]).reset_index().rename(columns = {0: 'margin_FB'}) #long

diff = get_diff(F)
diff_F = diff.stack([-2, -1]).reset_index().rename(columns = {0: 'margin_F'}) #long

diff = get_diff(FP)
diff_FP = diff.stack([-2, -1]).reset_index().rename(columns = {0: 'margin_FP'}) #long

diff = get_diff(FC)
diff_FC = diff.stack([-2, -1]).reset_index().rename(columns = {0: 'margin_FC'}) #long

# %%
diff_4Q = df.set_index(['ID','CN ID 4','PYOD','VAT', 'YEAR','QUARTER']).unstack([-2, -1]).sort_index(axis = 1)

# %%
diff_4Q = diff_4Q.fillna(0).diff(4, axis = 1) #table
diff_4Q = diff_4Q.replace(0, np.nan).stack([-2, -1]).reset_index().rename(columns = {'VART': 'VART_4Q_diff'}) #long

# %%
frac = .05
diff_4Q_margins = diff_4Q.sample(frac = frac).merge(
    diff_F, how = 'left').merge(diff_FP, how = 'left').merge(
    diff_FC, how = 'left').merge(diff_FPC, how = 'left').merge(diff_FB, how = 'left').merge(grs, how = 'left')

# %%
growth = diff_4Q_margins.loc[diff_4Q_margins.VART_4Q_diff > 0]
shrink = diff_4Q_margins.loc[diff_4Q_margins.VART_4Q_diff < 0]

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
margins_dec = pd.read_csv('./../../data/margins_desc.csv')

# %%
# s_list = []
for df in [shrink, growth]:
    grouped = df.groupby(['margin_F', 'margin_FP','margin_FC','margin_FPC', 'margin_FB', 'Category'])
    s = grouped['VART_4Q_diff'].sum()
    s = s/df.YEAR.nunique()/1e6/frac
    s = s.unstack().dropna()
    s = s.loc[s.sum(1).sort_values().index].round(-1)
    names = [name.replace('_', ' ') for name in s.index.names]
    s.index = pd.MultiIndex.from_tuples([tuple([int(i) for i in ix]) for ix in s.index.tolist()])
    s.index.names = names
#     s_list += [s]
    s = s.rename(columns=str).reset_index().merge(margins_dec, how = 'left').drop_duplicates().dropna()
    s = s.set_index(['margin F','margin FP','margin FC','margin FPC','margin FB'])
    display(s.style.bar(vmin = -3e4, vmax = 3e4, align='mid', color=['#d65f5f', '#5fba7d'], subset = ['Shrinkage','Fluctuation','Expansion']))
#     display(s)
# Out:
# <style  type="text/css" >
#     #T_37569b76_e22e_11e9_b9c3_eb2b19d447e1row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 33.6%, #d65f5f 33.6%, #d65f5f 50.0%, transparent 50.0%);
#         }    #T_37569b76_e22e_11e9_b9c3_eb2b19d447e1row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 2.5%, #d65f5f 2.5%, #d65f5f 50.0%, transparent 50.0%);
#         }    #T_37569b76_e22e_11e9_b9c3_eb2b19d447e1row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.2%, #d65f5f 45.2%, #d65f5f 50.0%, transparent 50.0%);
#         }    #T_37569b76_e22e_11e9_b9c3_eb2b19d447e1row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.8%, #d65f5f 45.8%, #d65f5f 50.0%, transparent 50.0%);
#         }    #T_37569b76_e22e_11e9_b9c3_eb2b19d447e1row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 40.3%, #d65f5f 40.3%, #d65f5f 50.0%, transparent 50.0%);
#         }    #T_37569b76_e22e_11e9_b9c3_eb2b19d447e1row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.1%, #d65f5f 48.1%, #d65f5f 50.0%, transparent 50.0%);
#         }    #T_37569b76_e22e_11e9_b9c3_eb2b19d447e1row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.2%, #d65f5f 44.2%, #d65f5f 50.0%, transparent 50.0%);
#         }    #T_37569b76_e22e_11e9_b9c3_eb2b19d447e1row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.6%, #d65f5f 46.6%, #d65f5f 50.0%, transparent 50.0%);
#         }    #T_37569b76_e22e_11e9_b9c3_eb2b19d447e1row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.0%, #d65f5f 49.0%, #d65f5f 50.0%, transparent 50.0%);
#         }    #T_37569b76_e22e_11e9_b9c3_eb2b19d447e1row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.0%, #d65f5f 48.0%, #d65f5f 50.0%, transparent 50.0%);
#         }    #T_37569b76_e22e_11e9_b9c3_eb2b19d447e1row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.2%, #d65f5f 46.2%, #d65f5f 50.0%, transparent 50.0%);
#         }    #T_37569b76_e22e_11e9_b9c3_eb2b19d447e1row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.4%, #d65f5f 49.4%, #d65f5f 50.0%, transparent 50.0%);
#         }    #T_37569b76_e22e_11e9_b9c3_eb2b19d447e1row4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.2%, #d65f5f 48.2%, #d65f5f 50.0%, transparent 50.0%);
#         }    #T_37569b76_e22e_11e9_b9c3_eb2b19d447e1row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.8%, #d65f5f 48.8%, #d65f5f 50.0%, transparent 50.0%);
#         }    #T_37569b76_e22e_11e9_b9c3_eb2b19d447e1row4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.5%, #d65f5f 49.5%, #d65f5f 50.0%, transparent 50.0%);
#         }    #T_37569b76_e22e_11e9_b9c3_eb2b19d447e1row5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.5%, #d65f5f 47.5%, #d65f5f 50.0%, transparent 50.0%);
#         }    #T_37569b76_e22e_11e9_b9c3_eb2b19d447e1row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.6%, #d65f5f 49.6%, #d65f5f 50.0%, transparent 50.0%);
#         }    #T_37569b76_e22e_11e9_b9c3_eb2b19d447e1row5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.7%, #d65f5f 49.7%, #d65f5f 50.0%, transparent 50.0%);
#         }    #T_37569b76_e22e_11e9_b9c3_eb2b19d447e1row6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.9%, #d65f5f 48.9%, #d65f5f 50.0%, transparent 50.0%);
#         }    #T_37569b76_e22e_11e9_b9c3_eb2b19d447e1row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.9%, #d65f5f 49.9%, #d65f5f 50.0%, transparent 50.0%);
#         }    #T_37569b76_e22e_11e9_b9c3_eb2b19d447e1row6_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 50.0%, transparent 50.0%);
#         }    #T_37569b76_e22e_11e9_b9c3_eb2b19d447e1row7_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.3%, #d65f5f 49.3%, #d65f5f 50.0%, transparent 50.0%);
#         }    #T_37569b76_e22e_11e9_b9c3_eb2b19d447e1row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.7%, #d65f5f 49.7%, #d65f5f 50.0%, transparent 50.0%);
#         }    #T_37569b76_e22e_11e9_b9c3_eb2b19d447e1row7_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.9%, #d65f5f 49.9%, #d65f5f 50.0%, transparent 50.0%);
#         }    #T_37569b76_e22e_11e9_b9c3_eb2b19d447e1row8_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.6%, #d65f5f 49.6%, #d65f5f 50.0%, transparent 50.0%);
#         }    #T_37569b76_e22e_11e9_b9c3_eb2b19d447e1row8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.8%, #d65f5f 49.8%, #d65f5f 50.0%, transparent 50.0%);
#         }    #T_37569b76_e22e_11e9_b9c3_eb2b19d447e1row8_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.9%, #d65f5f 49.9%, #d65f5f 50.0%, transparent 50.0%);
#         }</style><table id="T_37569b76_e22e_11e9_b9c3_eb2b19d447e1" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Shrinkage</th>        <th class="col_heading level0 col1" >Fluctuation</th>        <th class="col_heading level0 col2" >Expansion</th>        <th class="col_heading level0 col3" >Description</th>    </tr>    <tr>        <th class="index_name level0" >margin F</th>        <th class="index_name level1" >margin FP</th>        <th class="index_name level2" >margin FC</th>        <th class="index_name level3" >margin FPC</th>        <th class="index_name level4" >margin FB</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_37569b76_e22e_11e9_b9c3_eb2b19d447e1level0_row0" class="row_heading level0 row0" rowspan=6>0</th>
#                         <th id="T_37569b76_e22e_11e9_b9c3_eb2b19d447e1level1_row0" class="row_heading level1 row0" rowspan=4>0</th>
#                         <th id="T_37569b76_e22e_11e9_b9c3_eb2b19d447e1level2_row0" class="row_heading level2 row0" rowspan=2>0</th>
#                         <th id="T_37569b76_e22e_11e9_b9c3_eb2b19d447e1level3_row0" class="row_heading level3 row0" rowspan=2>0</th>
#                         <th id="T_37569b76_e22e_11e9_b9c3_eb2b19d447e1level4_row0" class="row_heading level4 row0" >0</th>
#                         <td id="T_37569b76_e22e_11e9_b9c3_eb2b19d447e
# <style  type="text/css" >
#     #T_3783c8b2_e22e_11e9_b9c3_eb2b19d447e1row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 50.1%, transparent 50.1%);
#         }    #T_3783c8b2_e22e_11e9_b9c3_eb2b19d447e1row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 50.3%, transparent 50.3%);
#         }    #T_3783c8b2_e22e_11e9_b9c3_eb2b19d447e1row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 51.1%, transparent 51.1%);
#         }    #T_3783c8b2_e22e_11e9_b9c3_eb2b19d447e1row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 50.2%, transparent 50.2%);
#         }    #T_3783c8b2_e22e_11e9_b9c3_eb2b19d447e1row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 50.6%, transparent 50.6%);
#         }    #T_3783c8b2_e22e_11e9_b9c3_eb2b19d447e1row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 50.9%, transparent 50.9%);
#         }    #T_3783c8b2_e22e_11e9_b9c3_eb2b19d447e1row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 50.1%, transparent 50.1%);
#         }    #T_3783c8b2_e22e_11e9_b9c3_eb2b19d447e1row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 50.4%, transparent 50.4%);
#         }    #T_3783c8b2_e22e_11e9_b9c3_eb2b19d447e1row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 53.0%, transparent 53.0%);
#         }    #T_3783c8b2_e22e_11e9_b9c3_eb2b19d447e1row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 50.7%, transparent 50.7%);
#         }    #T_3783c8b2_e22e_11e9_b9c3_eb2b19d447e1row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 51.8%, transparent 51.8%);
#         }    #T_3783c8b2_e22e_11e9_b9c3_eb2b19d447e1row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 52.4%, transparent 52.4%);
#         }    #T_3783c8b2_e22e_11e9_b9c3_eb2b19d447e1row4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 50.3%, transparent 50.3%);
#         }    #T_3783c8b2_e22e_11e9_b9c3_eb2b19d447e1row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 50.6%, transparent 50.6%);
#         }    #T_3783c8b2_e22e_11e9_b9c3_eb2b19d447e1row4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 55.4%, transparent 55.4%);
#         }    #T_3783c8b2_e22e_11e9_b9c3_eb2b19d447e1row5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 51.0%, transparent 51.0%);
#         }    #T_3783c8b2_e22e_11e9_b9c3_eb2b19d447e1row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 55.2%, transparent 55.2%);
#         }    #T_3783c8b2_e22e_11e9_b9c3_eb2b19d447e1row5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 51.9%, transparent 51.9%);
#         }    #T_3783c8b2_e22e_11e9_b9c3_eb2b19d447e1row6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 51.2%, transparent 51.2%);
#         }    #T_3783c8b2_e22e_11e9_b9c3_eb2b19d447e1row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 60.3%, transparent 60.3%);
#         }    #T_3783c8b2_e22e_11e9_b9c3_eb2b19d447e1row6_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 56.0%, transparent 56.0%);
#         }    #T_3783c8b2_e22e_11e9_b9c3_eb2b19d447e1row7_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 52.0%, transparent 52.0%);
#         }    #T_3783c8b2_e22e_11e9_b9c3_eb2b19d447e1row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 63.5%, transparent 63.5%);
#         }    #T_3783c8b2_e22e_11e9_b9c3_eb2b19d447e1row7_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 53.9%, transparent 53.9%);
#         }    #T_3783c8b2_e22e_11e9_b9c3_eb2b19d447e1row8_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 55.5%, transparent 55.5%);
#         }    #T_3783c8b2_e22e_11e9_b9c3_eb2b19d447e1row8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 100.0%, transparent 100.0%);
#         }    #T_3783c8b2_e22e_11e9_b9c3_eb2b19d447e1row8_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 66.2%, transparent 66.2%);
#         }</style><table id="T_3783c8b2_e22e_11e9_b9c3_eb2b19d447e1" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Shrinkage</th>        <th class="col_heading level0 col1" >Fluctuation</th>        <th class="col_heading level0 col2" >Expansion</th>        <th class="col_heading level0 col3" >Description</th>    </tr>    <tr>        <th class="index_name level0" >margin F</th>        <th class="index_name level1" >margin FP</th>        <th class="index_name level2" >margin FC</th>        <th class="index_name level3" >margin FPC</th>        <th class="index_name level4" >margin FB</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3783c8b2_e22e_11e9_b9c3_eb2b19d447e1level0_row0" class="row_heading level0 row0" rowspan=2>0</th>
#                         <th id="T_3783c8b2_e22e_11e9_b9c3_eb2b19d447e1level1_row0" class="row_heading level1 row0" >1</th>
#                         <th id="T_3783c8b2_e22e_11e9_b9c3_eb2b19d447e1level2_row0" class="row_heading level2 row0" >0</th>
#                         <th id="T_3783c8b2_e22e_11e9_b9c3_eb2b19d447e1level3_row0" class="row_heading level3 row0" >1</th>
#                         <th id="T_3783c8b2_e22e_11e9_b9c3_eb2b19d447e1level4_row0" class="row_heading level4 row0" >1</th>
#                         <td id="T_3783c8b2_e22e_11e9_b9c3_eb2b19d447e1row0_col0" class="data

# %%
# Vast majority are continuing. It is easier to have the country changing, rather than the product.

# %%
# The gaussian / fat tail characteristic of them should be merged here!!!

# %%
# for i in [0, 1]:   
#     df_level_g = df_level_g_list[i].sample(frac = .05)
#     df_level_g['annual_log_bin'] = pd.cut(df_level_g['annual_log'], np.arange(4, 10, .5))
    
#     # separate it into 2:
#     df_level_g_gauss = df_level_g.loc[abs(df_level_g.annual_logdiff - 0.015) < .075]
