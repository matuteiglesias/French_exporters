# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn
% matplotlib inline

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
data_path = './../../data/processed/'

df = pd.read_csv('./../../data/processed/ID_Y.csv')
df = df.loc[df.IMPORT == 0]
empirical = df.groupby(['YEAR']).agg({'ID': 'count', 'VART': 'sum'}) # count == nunique

# *think that mu, sigma are for pooled data, but they could be different in each year.

# %%
sales_ID = df.groupby(['ID'])['VART'].sum().sort_values()
Q = 20
q = pd.cut(np.cumsum(sales_ID)/sales_ID.sum(), Q)
q.value_counts() # Hay 12x menos que en el paper porque son ID, no ID, YEAR
# Out:
# (-0.001, 0.05]    407619
# (0.05, 0.1]         8595
# (0.1, 0.15]         3402
# (0.15, 0.2]         1754
# (0.2, 0.25]         1029
# (0.25, 0.3]          648
# (0.3, 0.35]          431
# (0.35, 0.4]          299
# (0.4, 0.45]          212
# (0.45, 0.5]          149
# (0.5, 0.55]          109
# (0.55, 0.6]           81
# (0.6, 0.65]           58
# (0.65, 0.7]           44
# (0.7, 0.75]           31
# (0.75, 0.8]           20
# (0.8, 0.85]           11
# (0.85, 0.9]            7
# (0.9, 0.95]            4
# (0.95, 1.0]            2
# Name: VART, dtype: int64

# %%
df_q = df.merge(q.reset_index(), on = 'ID')

y = df_q.groupby(['VART_y', 'YEAR'])['VART_x'].sum().reset_index()
y.columns = ['q', 'YEAR', 'y']

# %% [markdown]
# ## Ya tenemos los valores Y

# %%
# Lineal
y.set_index(['YEAR', 'q']).unstack().plot(c = '.5', alpha = .5)
y.set_index(['YEAR', 'q']).unstack().median(1).plot(c = 'r')
plt.legend(loc = (1, 0))
plt.show()

# Logs
np.log10(y.set_index(['YEAR', 'q']).unstack()).plot(c = '.5', alpha = .5)
np.log10(y.set_index(['YEAR', 'q']).unstack()).median(1).plot(c = 'r')
plt.legend(loc = (1, 0))
plt.show()

# %%
# Logs (y - median)
(np.log10(y.set_index(['YEAR', 'q']).unstack()).T - np.log10(y.set_index(['YEAR', 'q']).unstack()).median(1)).T.plot(c = '.5', alpha = .5)
plt.legend(loc = (1, 0))
plt.show()

# %%
Y = y.groupby('YEAR').sum()
logY = np.log10(Y)

# %%
x_ = logY.index
y_ = logY['y'].values
p = np.poly1d(np.polyfit(x_, y_, 1))
p
# Out:
# poly1d([ 1.30268034e-02, -1.45770647e+01])

# %%
## By definition, the mean value is THE SAME for both the line fit and the actual data.
np.mean(p(x_)) - np.mean(y_)
# Out:
# -7.105427357601002e-15

# %%
Y['L_C'] = np.power(10, p(x_))
Y['C'] = np.power(10, np.mean(p(x_))) # == np.mean(y_)
Y['L'] = Y['L_C'] - Y['C']
Y['mq'] = Q*y.set_index(['YEAR', 'q']).unstack().median(1) # Quantile medians
# Y['R'] = Y['y'] - Y['L_C']
Y['R'] = Y['mq'] - Y['L_C']

Y.plot()

# %%
## Coefficient Matrix
X = Y[['C', 'L', 'R']]
# X

# %%
data = y.set_index(['YEAR', 'q']).unstack()

# En este paso ajusto con un OLS simple por ahora, pero en realidad deberia tener un modelo lineal generalizado que incorpore el hecho que hacia el final de la seria todo esta escalado.
# Tiene que ir como la expectativa de Y, que es L + C

# Agarramos alguna de las series del q y lo ajustamos con las 3 componentes L, C, R.

# %%
a = X.values # MxN. M would be the time length, N would be how many variables.
b = data.values # MxK. OLS is computed for each of the k columns of b

# %%
x, residuals, rank, s = np.linalg.lstsq(a, b, rcond=None)

# %%
# plt.matshow(x)
plt.plot(x.T)
# Out:
# [<matplotlib.lines.Line2D at 0x7f95c8eddb70>,
#  <matplotlib.lines.Line2D at 0x7f95c8edda20>,
#  <matplotlib.lines.Line2D at 0x7f95c8edde10>]

# %% [markdown]
# ### Conclusion, restar (L + R) a yq (su porcion de deriva exponencial y shock agregado)

# %%
data_Cr = (data.T - (Y/Q)['L'] - (Y/Q)['R']).T
data_r = (data.T - (Y/Q)['L'] - (Y/Q)['R'] - (Y/Q)['C']).T
data_Rr = (data.T - (Y/Q)['L'] - (Y/Q)['C']).T

# %%
np.log10(data_Cr.var()).plot(marker = '.')

# %%
np.log10(data_Cr).corr().median().sort_values()
# Out:
#    q
# y  (0.6, 0.65]      -0.128330
#    (0.5, 0.55]      -0.127871
#    (0.4, 0.45]      -0.080453
#    (0.9, 0.95]      -0.067286
#    (0.8, 0.85]      -0.061328
#    (0.75, 0.8]      -0.002204
#    (0.95, 1.0]       0.003306
#    (0.3, 0.35]       0.026720
#    (0.85, 0.9]       0.031153
#    (0.1, 0.15]       0.047253
#    (0.55, 0.6]       0.053789
#    (0.35, 0.4]       0.057126
#    (0.65, 0.7]       0.077081
#    (0.7, 0.75]       0.102326
#    (-0.001, 0.05]    0.103584
#    (0.15, 0.2]       0.122175
#    (0.2, 0.25]       0.126798
#    (0.45, 0.5]       0.145932
#    (0.05, 0.1]       0.157145
#    (0.25, 0.3]       0.323018
# dtype: float64

# %%
plt.matshow(data_Cr.corr())

# %%
plt.matshow(np.log10(data_Cr).corr())

# %%
# np.round(data_r.corr(), 2)
plt.matshow(np.round(data_r.corr(), 2))

# %%
plt.matshow(np.round(data_Rr.corr(), 2))

# %%
import scipy.linalg as la
C = data_Rr.corr()
# C = data_r.corr()
# C = np.log10(data_Cr)
# C = data_Cr.corr()#/8e18

# %%
fig, axs = plt.subplots(1, 4, figsize = (16, 4))
cm = 'PiYG'
n_corte = 5 # ~20

avals, avecs = la.eig(C.values)
avals = np.real(avals) # == np.abs(avals)
def component(k, avals = avals, avecs = avecs):
    uk = np.array(len(avals)*[avecs.T[k]]).reshape(avecs.shape) # la componente k agarra el elemento k de todos los autovectores.
    return np.real(avals[k]*np.multiply(uk.T, uk))

C_s = component(0) # structural component
C_g = np.array([component(i) for i in range(1, n_corte)]).sum(axis=0) # random component
C_r = np.array([component(i) for i in range(n_corte, len(avals))]).sum(axis=0) # random component

axs[0].matshow(C, vmin = -1, vmax = 1, cmap = cm); axs[0].set_xlabel('Similarity Matrix')
axs[0].set_ylabel('COSINE')
axs[1].matshow(C_s, vmin = -1, vmax = 1, cmap = cm); axs[1].set_xlabel('Main component')
axs[2].matshow(C_g, vmin = -1, vmax = 1, cmap = cm); axs[2].set_xlabel('Groups component')
axs[3].matshow(C_r, vmin = -1, vmax = 1, cmap = cm); axs[3].set_xlabel('Noise component')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Veamos la combinacion de las varianzas.

# %%
# Por como descompusimos la serie del total:
# Y['y'] = Y['C'] + Y['L'] + Y['R'] + data_r.sum(1)
Y['y'].var()/1e20
# Out:
# 31.33103239847797

# %%
concat = pd.concat([Y['C'], Y['L'], Y['R'], data_r['y']], axis = 1)

# %%
# La identidad esta. Habria que ver como son las componentes.
# Y['y'].var() == cov.sum().sum()

cov = concat.cov()

cov.columns = list(cov.columns[:-Q]) + Q*['qs']
cov.index = list(cov.index[:-Q]) + Q*['qs']

grouped_cov = cov.unstack().groupby(level = (0, 1)).sum().unstack()

# %%
grouped_cov/1e20
# Out:
#       C          L         R        qs
# C   0.0   0.000000  0.000000  0.000000
# L   0.0  28.277661 -2.116907  1.196992
# R   0.0  -2.116907  5.978785 -0.743830
# qs  0.0   1.196992 -0.743830  0.402075

# %%
data_r['y'].var().sum()/1e20
# Out:
# 1.171525363254486

# %%
(data_r['y'].cov().sum().sum() - data_r['y'].var().sum())/1e20
# Out:
# -0.769450373429369

# %%
## Now, do the same but without the line and constant terms already out.

# Y['Y - C_L'] = Y['R'] + data_r.sum(1)

concat = pd.concat([Y['R'], data_r['y']], axis = 1)
cov = concat.cov()

cov.columns = list(cov.columns[:-Q]) + Q*['qs']
cov.index = list(cov.index[:-Q]) + Q*['qs']

grouped_cov = cov.unstack().groupby(level = (0, 1)).sum().unstack()

# %%
(Y['y'] - Y['L_C']).var()/1e20
# Out:
# 4.8932005007718375

# %%
grouped_cov/1e20
# Out:
#            R        qs
# R   5.978785 -0.743830
# qs -0.743830  0.402075

# %%
np.diag(data_r['y'].cov().values)
# Out:
# 1.171525363254486e+20

# %%
# ld = data_Rr.cov().where(~np.triu(np.ones(data_Cr.cov().shape)).astype(np.bool))
# 2*ld.sum().sum()
# Out:
# 3.497118861970013e+20

# %%
# Sum of Cov matrix is really near zero. # Not zero, probably because of nuemrical imprecision. 

# It means that the off diagonal elements conteract directly the sum of all variances.

# %%
# points['var_diff_agg_i'] = np.log10(value_sum).diff(axis = 1).var(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-143-3715ee9d63f4> in <module>()
# ----> 1 points['var_diff_agg_i'] = np.log10(value_sum).diff(axis = 1).var(1)
#
# NameError: name 'value_sum' is not defined

# %%
# Creo una tabla de 
Q = 25
T = 100

# var_r = 0.004**2 ### se mueve s.std(1) +-1
var_r = 0.04**2 ### se mueve s.std(1) +-10 en cada q

r = np.random.normal(0, np.sqrt(var_r), T) # Es normal. Hay que agregarsela a los logs, no a lo lineal, pero si esta cerca del 1% es logs y lineal se aproxima. Para eso, sumamos al logaritmo un error y pedimos que sea de cerca de 1%.

t0 = pd.DataFrame(2*np.ones((Q, T))) # Una matrix de 100's -> 10Q suman 1000, logs son 2 y 3, copado.
# Asi va a estar bien planteada en logs, pero no se si va a dar bien su suma. Para eso querriamos que la distribucion fuera normal en lineal. Casi se cumple, pero da error numerico.,
# Igual quizas este queda muy debajo de error de probabilidad, igual...


# # Apply general shock

tr = t0 + r
# tr - t0 = pd.concat(Q*[pd.Series(r)], axis = 1).T

tq = t0.copy()
tq.loc[0] = tq.loc[0] + r

s0 = np.power(10, t0)
sr = np.power(10, tr)
sq = np.power(10, tq)

# %%
# # Creo una tabla de 
# Q = 10
# T = 2700

# var_r = 10
# r = np.random.normal(0, np.sqrt(var_r), T)


# s = pd.DataFrame(np.power(10, np.log10(100*np.ones((10, T)))))
# # # Apply general shock
# # s = s + r
# # Apply shock on first row
# s.loc[0] = s.loc[0] + r
# t = np.log10(s)

# %%
# np.log10(s).var(1)   # variance of the log levels ## cambie t por s

# %%
# s.var(1) # Variance in linear levels ## cambie t por s

# %%
# np.log10(s).var(1)/np.log10(s.sum()).var() # Q**2   ### Ratio between variance in the log level of quantile to variance of log level of total
## cambie t por s

# %%
# La suma de las covarianzas es el sigma cuadrado que tiene la suma.
# Aca asumimos que habia un shock uniforme para todos, que seria como una constante en la matriz de covarianza.
# Tanto en lineal como en logs la cuenta da EXACTA

# sr.sum().var() = sr.T.cov().sum().sum()

# tr.sum().var() = tr.T.cov().sum().sum()

# %%
sr.sum().var()/Q**2
# Out:
# 86.8570153034441

# %%
sr.T.cov().sum().sum()/Q**2
# Out:
# 86.85701530344406

# %%
tr.sum().var()/Q**2
# Out:
# 0.0017026316630745035

# %%
tr.T.cov().sum().sum()/Q**2
# Out:
# 0.0017026316630745016

# %%
sq.sum().var()
# Out:
# 86.8570153034442

# %%
sq.T.cov().sum().sum()
# Out:
# 86.85701530344406

# %%
tq.sum().var()
# Out:
# 0.0017026316630745207

# %%
tq.T.cov().sum().sum()
# Out:
# 0.0017026316630745014

# %%
# Yo estaba con:
np.log10(sr.sum()).var()  # En este caso si me da esta identidad.
# Out:
# 0.0017026316630745027

# %%
np.log10(sq.sum()).var()
# Out:
# 2.623262901834125e-06

# %%
 ## Aproximadamente cerca de Q**2 pero no completamente
np.log10(sr.sum()).var()/np.log10(sq.sum()).var()
# Out:
# 649.0510965881696

# %%
xx

# %%
np.log10(110)-2
# Out:
# 0.04139268515822492

# %%
np.log10(s).var(1)   # variance of the log levels
# Out:
# 0    0.000797
# 1    0.000198
# 2    0.000198
# 3    0.000198
# 4    0.000198
# 5    0.000198
# 6    0.000198
# 7    0.000198
# 8    0.000198
# 9    0.000198
# dtype: float64

# %%
np.cov(np.log10(s.loc[0]), np.log10(r))
# Out:
# /home/miglesia/anaconda2/envs/my_pymc_env/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in log10
#   """Entry point for launching an IPython kernel.
# array([[0.00079653,        nan],
#        [       nan,        nan]])

# %%
s.var(1) # Variance in linear levels
# Out:
# 0    10.019405
# 1    10.019405
# 2    10.019405
# 3    10.019405
# 4    10.019405
# 5    10.019405
# 6    10.019405
# 7    10.019405
# 8    10.019405
# 9    10.019405
# dtype: float64

# %%
np.log10(s).var(1)/np.log10(s.sum()).var() # Q**2   ### Ratio between variance in the log level of quantile to variance of log level of total
# Out:
# 0    3.329084
# 1    0.826023
# 2    0.826023
# 3    0.826023
# 4    0.826023
# 5    0.826023
# 6    0.826023
# 7    0.826023
# 8    0.826023
# 9    0.826023
# dtype: float64

# %%
# LHS
np.log10(s.sum()).var()
# Out:
# 0.00018901097897712263

# %%
#RHS

# %%
s
# Out:
#         0          1           2           3           4          5     \
# 0  89.711679  100.19879  102.886974  100.587316  100.958905  97.127861
# 1  89.711679  100.19879  102.886974  100.587316  100.958905  97.127861
# 2  89.711679  100.19879  102.886974  100.587316  100.958905  97.127861
# 3  89.711679  100.19879  102.886974  100.587316  100.958905  97.127861
# 4  89.711679  100.19879  102.886974  100.587316  100.958905  97.127861
# 5  89.711679  100.19879  102.886974  100.587316  100.958905  97.127861
# 6  89.711679  100.19879  102.886974  100.587316  100.958905  97.127861
# 7  89.711679  100.19879  102.886974  100.587316  100.958905  97.127861
# 8  89.711679  100.19879  102.886974  100.587316  100.958905  97.127861
# 9  89.711679  100.19879  102.886974  100.587316  100.958905  97.127861
#
#          6           7           8          9     ...       2690       2691  \
# 0  103.156315  100.714043  100.292575  99.472642  ...  99.713762  99.221558
# 1  103.156315  100.714043  100.292575  99.472642  ...  99.713762  99.221558
# 2  103.156315  100.714043  100.292575  99.472642  ...  99.713762  99.221558
# 3  103.156315  100.714043  100.292575  99.472642  ...  99.713762  99.221558
# 4  103.156315  100.714043  100.292575  99.472642  ...  99.713762  99.221558
# 5  103.156315  100.714043  100.292575  99.472642  ...  99.713762  99.221558
# 6  103.156315  100.714043  100.292575  99.472642  ...  99.713762  99.221558
# 7  103.156315  100.714043  100.292575  99.472642  ...  99.713762  99.221558
# 8  103.156315  100.714043  100.292575  99.472642  ...  99.713762  99.221558
# 9  103.156315  100.714043  100.292575  99.472642  ...  99.713762  99.221558
#
#          2692       2693       2694       2695       2696       2697  \
# 0  100.411975  97.982814  96.077889  98.446071  97.872728  99.201973
# 1  100.411975  97.982814  96.077889  98.446071  97.872728  99.201973
# 2  100.411975  97.982814  96.077889  98.446071  97.872728  99.201973
# 3  100.411975  97.982814  96.077889  98.446071  97.872728  99.201973
# 4  100.411975  97.982814  96.077889  98.446071  97.872728  99.201973
# 5  100.411975  97.982814  96.077889  98.446071  97.872728  99.201973
# 6  100.411975  97.982814  96.077889  98.446071  97.872728  99.201973
# 7  100.411975  97.982814  96.077889  98.446071  97.872728  99.201973
# 8  100.411975  97.982814  96.077889  98.446071  97.872728  99.201973
# 9  100.411975  97.982814  96.077889  98.446071  97.872728  99.201973
#
#         2698        2699
# 0  99.624819  101.960279
# 1  99.624819  101.960279
# 2  99.624819  101.960279
# 3  99.624819  101.960279
# 4  99.624819  101.960279
# 5  99.624819  101.960279
# 6  99.624819  101.960279
# 7  99.624819  101.960279
# 8  99.624819  101.960279
# 9  99.624819  101.960279
#
# [10 rows x 2700 columns]
