# %%
import pandas as pd
import numpy as np
import binet as bnt

# %%
#Or from file if you have it.
wt = pd.read_csv('./../../data/wt/wt.csv')
wt = wt.loc[(wt.year > 2005) & (wt.year < 2014)]
pr = pd.read_csv('./../../data/wt/pr.csv')
co = pd.read_csv('./../../data/wt/co.csv')

# %%
wt_fra = wt.loc[wt.ccode == 'fra']

# %%
df = pd.read_csv('./../../data/processed/CN_ID_4_FY.csv')
df = df.loc[df.IMPORT == 0]
df = df.rename(columns = {'YEAR': 'year'})

# %%
fl_fra = df.groupby(['year', 'CN ID 4'])['VART'].sum().reset_index()

# %%
prods_wt = wt_fra.groupby(['year','pcode'])['x'].sum().sort_values(ascending = False).reset_index()
prods_fl = fl_fra.groupby(['year','CN ID 4'])['VART'].sum().sort_values(ascending = False).reset_index()

# %%
merged = prods_wt.merge(prods_fl, left_on = ['pcode', 'year'], right_on = ['CN ID 4', 'year'], how = 'outer')

merged = merged.dropna()
merged = merged.set_index(['year', 'pcode'])
df = pd.DataFrame(merged.x/merged.VART, columns=['ratio'])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.hist((merged.x/merged.VART).clip(0, 3.5), 50)
plt.show()
# Out:
# /home/miglesia/anaconda2/envs/my_pymc_env/lib/python3.6/site-packages/numpy/lib/histograms.py:720: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/miglesia/anaconda2/envs/my_pymc_env/lib/python3.6/site-packages/numpy/lib/histograms.py:721: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
df.unstack().T.round(2).sample(20)
# Out:
# year          2006   2007   2008  2009  2010  2011  2012  2013
#       pcode
# ratio 3907.0  1.73   1.78   2.05  2.00  1.23  1.27  1.21  1.34
#       4401.0  1.65   1.76   2.73  2.03  1.60  1.67  1.10  0.75
#       2401.0  8.48  10.90  10.49  1.17  1.26  1.04  1.08  0.95
#       8410.0  4.65   8.26   7.01  8.51  1.45  1.26  0.91  1.07
#       6002.0  1.15   1.21   1.34  1.21  1.17  0.76  0.99  1.08
#       8450.0  1.02   1.23   1.29  1.28  1.28  1.27  1.13  1.11
#       5506.0  2.16   1.77   2.17  1.17  1.40  1.29  1.21  1.26
#       5503.0  2.42   1.05   1.13  0.95  0.90  0.94  0.84  0.92
#       6912.0  0.99   1.05   1.16  1.08  1.07  1.16  1.01  1.19
#       1901.0  1.08   1.20   1.35  1.28  1.23  1.27  1.17  1.22
#       5512.0  1.08   1.22   1.45  1.34  1.27  1.31  1.14  1.21
#       2840.0  1.12   1.19   1.46  1.53  1.30  1.35  1.13  0.97
#       5811.0  4.62   3.50   4.27  1.49  3.40  2.42  3.32  2.70
#       6004.0  1.01   1.19   1.23  1.08  1.09  1.34  1.08  1.09
#       8476.0  1.22   1.46   1.46  1.13  1.20  1.72  1.05  1.13
#       8708.0  7.68   1.12   1.31  1.25  1.20  1.11  1.22  1.05
#       4413.0  1.29   1.44   1.88  2.24  1.83  1.28  1.30  2.42
#       7310.0  1.18   1.26   1.32  1.49  1.41  1.39  1.20  1.51
#       6214.0  1.21   1.41   1.42  1.32  1.18  1.30  1.26  1.30
#       101.0    NaN    NaN    NaN   NaN   NaN   NaN  0.73  0.73
